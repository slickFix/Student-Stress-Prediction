# %%
### importing libraries

from datetime import datetime,timedelta
from collections import defaultdict
from tqdm import tqdm

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import json
import os
import gc

from lightgbm import LGBMClassifier
import optuna

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,roc_curve,confusion_matrix,accuracy_score,auc,classification_report

# %% [markdown]
# ## load dataset

# %%
df1 = pd.read_csv('./data/sensing_data_2.csv')
df1.head()
# Out:
#   user_id            date_time  activity_inf_stationary_count  \
# 0     u17  2013-03-28 15:08:00                          13383
# 1     u17  2013-03-30 16:06:00                          15997
# 2     u17  2013-04-11 16:53:00                          15634
# 3     u17  2013-04-14 15:33:00                          16525
# 4     u17  2013-04-15 14:07:00                          15631
#
#    activity_inf_walking_count  activity_inf_running_count  \
# 0                         720                         109
# 1                         382                           6
# 2                         738                          15
# 3                         117                           0
# 4                         669                          83
#
#    activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 0                         254                              8
# 1                         111                             12
# 2                         128                             11
# 3                          29                              6
# 4                         187                             15
#
#    app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 0                                7                               19
# 1                               10                               23
# 2                               10                               13
# 3                                6                                6
# 4                               14                               22
#
#    app_usage_baseActivity_numActivities  ...  year  month  day  hours  minute  \
# 0                                   409  ...  2013      3   28     15       8
# 1                                   842  ...  2013      3   30     16       6
# 2                                   736  ...  2013      4   11     16      53
# 3                                  1809  ...  2013      4   14     15      33
# 4                                  1498  ...  2013      4   15     14       7
#
#    weekday  weeknumber  label_source  rating  stress_label
# 0      Thu          12    stress_ema       1             0
# 1      Sat          12    stress_ema       2             1
# 2      Thu          14    stress_ema       3             1
# 3      Sun          14    stress_ema       3             1
# 4      Mon          15    stress_ema       3             1
#
# [5 rows x 38 columns]

# %%
df1.columns,df1.columns[-10:]
# Out:
# (Index(['user_id', 'date_time', 'activity_inf_stationary_count',
#         'activity_inf_walking_count', 'activity_inf_running_count',
#         'activity_inf_unknown_count', 'app_usage_baseActivity_mClass',
#         'app_usage_baseActivity_mPackage', 'app_usage_baseActivity_id_count',
#         'app_usage_baseActivity_numActivities',
#         'app_usage_baseActivity_numRunning', 'app_usage_topActivity_mClass',
#         'app_usage_topActivity_mPackage', 'audio_inf_silence_count',
#         'audio_inf_voice_count', 'audio_inf_noise_count',
#         'audio_inf_unknown_count', 'conversation_hours', 'conversation_minutes',
#         'dark_hours', 'dark_minutes', 'dark_seconds', 'phonecharge_hours',
#         'phonecharge_minutes', 'phonecharge_seconds', 'phonelock_hours',
#         'phonelock_minutes', 'phonelock_seconds', 'year', 'month', 'day',
#         'hours', 'minute', 'weekday', 'weeknumber', 'label_source', 'rating',
#         'stress_label'],
#        dtype='object'),
#  Index(['year', 'month', 'day', 'hours', 'minute', 'weekday', 'weeknumber',
#         'label_source', 'rating', 'stress_label'],
#        dtype='object'))

# %%
df1 = df1.drop(df1.columns[-10:],axis=1)
df1.columns
# Out:
# Index(['user_id', 'date_time', 'activity_inf_stationary_count',
#        'activity_inf_walking_count', 'activity_inf_running_count',
#        'activity_inf_unknown_count', 'app_usage_baseActivity_mClass',
#        'app_usage_baseActivity_mPackage', 'app_usage_baseActivity_id_count',
#        'app_usage_baseActivity_numActivities',
#        'app_usage_baseActivity_numRunning', 'app_usage_topActivity_mClass',
#        'app_usage_topActivity_mPackage', 'audio_inf_silence_count',
#        'audio_inf_voice_count', 'audio_inf_noise_count',
#        'audio_inf_unknown_count', 'conversation_hours', 'conversation_minutes',
#        'dark_hours', 'dark_minutes', 'dark_seconds', 'phonecharge_hours',
#        'phonecharge_minutes', 'phonecharge_seconds', 'phonelock_hours',
#        'phonelock_minutes', 'phonelock_seconds'],
#       dtype='object')

# %%
df2 = pd.read_csv('./data/ema_data_2.csv')
df2.head()
# Out:
#   user_id            date_time  number_Social  experience_Class_neutral  \
# 0     u22  2013-03-27 00:35:00              0                         0
# 1     u22  2013-03-27 15:03:00              2                         1
# 2     u22  2013-03-27 20:06:00              2                         2
# 3     u22  2013-03-28 00:20:00             22                         2
# 4     u22  2013-03-28 03:00:00            232                         2
#
#    experience_Class_st_agree  experience_Class_agree  \
# 0                          0                       0
# 1                          0                       0
# 2                          0                       1
# 3                          0                       1
# 4                          0                       1
#
#    experience_Class_disagree  experience_Class_st_disagree  due_Class_yes  \
# 0                          0                             0              0
# 1                          0                             0              0
# 2                          0                             0              0
# 3                          0                             0              0
# 4                          0                             0              0
#
#    due_Class_no  ...  year  month  day  hours  minute  weekday  weeknumber  \
# 0             0  ...  2013      3   27      0      35      Wed          12
# 1             1  ...  2013      3   27     15       3      Wed          12
# 2             3  ...  2013      3   27     20       6      Wed          12
# 3             3  ...  2013      3   28      0      20      Thu          12
# 4             3  ...  2013      3   28      3       0      Thu          12
#
#    label_source  rating  stress_label
# 0    stress_ema       1             0
# 1    stress_ema       1             0
# 2    stress_ema       4             0
# 3    stress_ema       5             0
# 4    stress_ema       5             0
#
# [5 rows x 66 columns]

# %%
df = df1.merge(df2,on=['user_id','date_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2455 entries, 0 to 2454
# Data columns (total 92 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   user_id                               2455 non-null   object
#  1   date_time                             2455 non-null   object
#  2   activity_inf_stationary_count         2455 non-null   int64
#  3   activity_inf_walking_count            2455 non-null   int64
#  4   activity_inf_running_count            2455 non-null   int64
#  5   activity_inf_unknown_count            2455 non-null   int64
#  6   app_usage_baseActivity_mClass         2455 non-null   int64
#  7   app_usage_baseActivity_mPackage       2455 non-null   int64
#  8   app_usage_baseActivity_id_count       2455 non-null   int64
#  9   app_usage_baseActivity_numActivities  2455 non-null   int64
#  10  app_usage_baseActivity_numRunning     2455 non-null   int64
#  11  app_usage_topActivity_mClass          2455 non-null   int64
#  12  app_usage_topActivity_mPackage        2455 non-null   int64
#  13  audio_inf_silence_count               2455 non-null   int64
#  14  audio_inf_voice_count                 2455 non-null   int64
#  15  audio_inf_noise_count                 2455 non-null   int64
#  16  audio_inf_unknown_count               2455 non-null   int64
#  17  conversation_hours                    2455 non-null   int64
#  18  conversation_minutes                  2455 non-null   int64
#  19  dark_hours                            2455 non-null   int64
#  20  dark_minutes                          2455 non-null   int64
#  81  grade_C_min                           2455 non-null   int64
#  82  year                                  2455 non-null   int64
#  83  month                                 2455 non-null   int64
#  84  day                                   2455 non-null   int64
#  85  hours                                 2455 non-null   int64
#  86  minute                                2455 non-null   int64
#  87  weekday                               2455 non-null   object
#  88  weeknumber                            2455 non-null   int64
#  89  label_source                          2455 non-null   object
#  90  rating                                2455 non-null   int64
#  91  stress_label                          2455 non-null   int64
# dtypes: int64(88), object(4)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#        activity_inf_stationary_count  activity_inf_walking_count  \
# count                    2455.000000                 2455.000000
# mean                    17247.491650                  997.328310
# std                     13703.392908                 1390.389219
# min                         0.000000                    0.000000
# 25%                     13468.000000                  391.000000
# 50%                     15026.000000                  618.000000
# 75%                     15739.000000                  959.500000
# max                     75287.000000                11208.000000
#
#        activity_inf_running_count  activity_inf_unknown_count  \
# count                 2455.000000                 2455.000000
# mean                   246.898167                  655.269246
# std                    392.034710                 1145.097115
# min                      0.000000                    0.000000
# 25%                     23.000000                  123.000000
# 50%                    107.000000                  250.000000
# 75%                    305.500000                  512.500000
# max                   7982.000000                 8340.000000
#
#        app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# count                    2455.000000                      2455.000000
# mean                       19.185336                        16.978411
# std                        10.315967                         8.803937
# min                         0.000000                         0.000000
# 25%                        12.000000                        11.000000
# 50%                        18.000000                        16.000000
# 75%                        25.000000                        22.000000
# max                        73.000000                        62.000000
#
#        app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# count                      2455.000000                           2455.000000
# mean                         30.044807                           2305.955193
# std                          17.520312                           2457.601158
# min                           0.000000                              0.000000
# 25%                          18.000000                            895.000000
# 50%                          27.000000                           1765.000000
# 75%                          40.000000                           2767.500000
# max                         145.000000                          18229.000000
#
#        app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# count                        2455.000000                   2455.000000  ...
# mean                         1329.231772                     23.809776  ...
# std                           905.765832                     13.114196  ...
# min                             0.000000                      0.000000  ...
# 25%                           569.500000                     15.000000  ...
# 50%                          1142.000000                     23.000000  ...
# 75%                          1930.500000                     32.000000  ...
# max                          6402.000000                     97.000000  ...
#
#        grade_C  grade_C_min    year        month          day        hours  \
# count   2455.0       2455.0  2455.0  2455.000000  2455.000000  2455.000000
# mean       0.0          0.0  2013.0     4.224847    15.397963    14.274134
# std        0.0          0.0     0.0     0.664591     9.455342     6.510618
# min        0.0          0.0  2013.0     3.000000     1.000000     0.000000
# 25%        0.0          0.0  2013.0     4.000000     7.000000    11.000000
# 50%        0.0          0.0  2013.0     4.000000    15.000000    15.000000
# 75%        0.0          0.0  2013.0     5.000000    25.000000    19.000000
# max        0.0          0.0  2013.0     6.000000    31.000000    23.000000
#
#             minute   weeknumber       rating  stress_label
# count  2455.000000  2455.000000  2455.000000   2455.000000
# mean     24.409369    15.600815     2.182077      0.291650
# std      18.665454     2.711081     1.294401      0.454614
# min       0.000000    12.000000     1.000000      0.000000
# 25%       7.000000    13.000000     1.000000      0.000000
# 50%      22.000000    15.000000     2.000000      0.000000
# 75%      40.000000    18.000000     3.000000      1.000000
# max      59.000000    22.000000     5.000000      1.000000
#
# [8 rows x 88 columns]

# %% [markdown]
# ## Dropping columns

# %%
df = df.sample(frac= 1,random_state=2022)
df
# Out:
#      user_id            date_time  activity_inf_stationary_count  \
# 2391     u33  2013-04-04 23:42:00                          15458
# 1383     u27  2013-04-15 21:00:00                          15361
# 962      u41  2013-04-08 22:47:00                           2037
# 1063     u39  2013-04-16 23:34:00                          16186
# 2292     u49  2013-05-16 19:11:00                          29497
# ...      ...                  ...                            ...
# 1713     u08  2013-03-26 19:04:00                              0
# 624      u36  2013-04-17 01:55:00                          15633
# 173      u51  2013-04-30 17:06:00                          15973
# 1244     u10  2013-04-08 21:04:00                          15544
# 893      u58  2013-04-02 18:04:00                          15666
#
#       activity_inf_walking_count  activity_inf_running_count  \
# 2391                         636                          80
# 1383                         486                          10
# 962                            1                           0
# 1063                         147                          19
# 2292                        1314                         232
# ...                          ...                         ...
# 1713                           0                           0
# 624                          406                         132
# 173                          226                         350
# 1244                         651                          52
# 893                          514                          61
#
#       activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 2391                         142                             49
# 1383                         379                             14
# 962                            2                              8
# 1063                         240                              6
# 2292                         202                             24
# ...                          ...                            ...
# 1713                           0                             13
# 624                          244                             24
# 173                           19                              7
# 1244                         114                             10
# 893                          217                             18
#
#       app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 2391                               45                               53
# 1383                               13                               58
# 962                                 7                                9
# 1063                                6                                9
# 2292                               20                               31
# ...                               ...                              ...
# 1713                               11                               20
# 624                                20                               34
# 173                                 7                               13
# 1244                               10                               18
# 893                                17                               33
#
#       app_usage_baseActivity_numActivities  ...  year  month  day  hours  \
# 2391                                 16757  ...  2013      4    4     23
# 1383                                  1287  ...  2013      4   15     21
# 962                                     98  ...  2013      4    8     22
# 1063                                   616  ...  2013      4   16     23
# 2292                                  2678  ...  2013      5   16     19
# ...                                    ...  ...   ...    ...  ...    ...
# 1713                                  1185  ...  2013      3   26     19
# 624                                   2042  ...  2013      4   17      1
# 173                                    682  ...  2013      4   30     17
# 1244                                  1421  ...  2013      4    8     21
# 893                                   1781  ...  2013      4    2     18
#
#       minute  weekday  weeknumber  label_source  rating  stress_label
# 2391      42      Thu          13    stress_ema       1             0
# 1383       0      Mon          15    stress_ema       1             0
# 962       47      Mon          14    stress_ema       1             0
# 1063      34      Tue          15    stress_ema       1             0
# 2292      11      Thu          19    stress_ema       5             0
# ...      ...      ...         ...           ...     ...           ...
# 1713       4      Tue          12    stress_ema       2             1
# 624       55      Wed          15    stress_ema       2             1
# 173        6      Tue          17    stress_ema       3             1
# 1244       4      Mon          14    stress_ema       5             0
# 893        4      Tue          13    stress_ema       1             0
#
# [2455 rows x 92 columns]

# %%
df = df.drop(['user_id','date_time','year','label_source','rating'],axis=1)

df['stress_label'].value_counts()
# Out:
# 0    1739
# 1     716
# Name: stress_label, dtype: int64

# %%
df['weekday'].value_counts()
# Out:
# Wed    392
# Tue    385
# Thu    375
# Fri    373
# Mon    362
# Sun    330
# Sat    238
# Name: weekday, dtype: int64

# %%
weekday_map = {"Sat":0,"Sun":1,"Mon":2,"Tue":3,"Wed":4,"Thu":5,"Fri":6}

df['weekday'] = df['weekday'].map(weekday_map)

df['weekday'].value_counts()
# Out:
# 4    392
# 3    385
# 5    375
# 6    373
# 2    362
# 1    330
# 0    238
# Name: weekday, dtype: int64

# %%
df = df.reset_index(drop=True)
df
# Out:
#       activity_inf_stationary_count  activity_inf_walking_count  \
# 0                             15458                         636
# 1                             15361                         486
# 2                              2037                           1
# 3                             16186                         147
# 4                             29497                        1314
# ...                             ...                         ...
# 2450                              0                           0
# 2451                          15633                         406
# 2452                          15973                         226
# 2453                          15544                         651
# 2454                          15666                         514
#
#       activity_inf_running_count  activity_inf_unknown_count  \
# 0                             80                         142
# 1                             10                         379
# 2                              0                           2
# 3                             19                         240
# 4                            232                         202
# ...                          ...                         ...
# 2450                           0                           0
# 2451                         132                         244
# 2452                         350                          19
# 2453                          52                         114
# 2454                          61                         217
#
#       app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# 0                                49                               45
# 1                                14                               13
# 2                                 8                                7
# 3                                 6                                6
# 4                                24                               20
# ...                             ...                              ...
# 2450                             13                               11
# 2451                             24                               20
# 2452                              7                                7
# 2453                             10                               10
# 2454                             18                               17
#
#       app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# 0                                  53                                 16757
# 1                                  58                                  1287
# 2                                   9                                    98
# 3                                   9                                   616
# 4                                  31                                  2678
# ...                               ...                                   ...
# 2450                               20                                  1185
# 2451                               34                                  2042
# 2452                               13                                   682
# 2453                               18                                  1421
# 2454                               33                                  1781
#
#       app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# 0                                  3155                            59  ...
# 1                                  1205                            20  ...
# 2                                    94                             9  ...
# 3                                   608                             7  ...
# 4                                  2443                            25  ...
# ...                                 ...                           ...  ...
# 2450                               1071                            14  ...
# 2451                               1685                            28  ...
# 2452                                676                             8  ...
# 2453                               1359                            12  ...
# 2454                               1689                            21  ...
#
#       grade_C_plu  grade_C  grade_C_min  month  day  hours  minute  weekday  \
# 0               0        0            0      4    4     23      42        5
# 1               0        0            0      4   15     21       0        2
# 2               0        0            0      4    8     22      47        2
# 3               0        0            0      4   16     23      34        3
# 4               0        0            0      5   16     19      11        5
# ...           ...      ...          ...    ...  ...    ...     ...      ...
# 2450            0        0            0      3   26     19       4        3
# 2451            0        0            0      4   17      1      55        4
# 2452            0        0            0      4   30     17       6        3
# 2453            0        0            0      4    8     21       4        2
# 2454            0        0            0      4    2     18       4        3
#
#       weeknumber  stress_label
# 0             13             0
# 1             15             0
# 2             14             0
# 3             15             0
# 4             19             0
# ...          ...           ...
# 2450          12             1
# 2451          15             1
# 2452          17             1
# 2453          14             0
# 2454          13             0
#
# [2455 rows x 87 columns]

# %% [markdown]
# ## Train val split

# %%
df_train,df_val,df_test = df[:(len(df)*3)//5],df[(len(df)*3)//5:(len(df)*4)//5],df[(len(df)*4)//5:]

len(df_train),len(df_val),len(df_test)
# Out:
# (1473, 491, 491)

# %%
df_train[df_train.columns[-1]]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1468    0
# 1469    0
# 1470    0
# 1471    0
# 1472    0
# Name: stress_label, Length: 1473, dtype: int64

# %% [markdown]
# ## LGBM

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 500)
  min_child_samples_hp = trial.suggest_int('min_child_samples', 10, 100)
  num_leaves_hp = trial.suggest_int('num_leaves', 2, 256)
  learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
  
  model = LGBMClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_child_samples = min_child_samples_hp,
                         num_leaves = num_leaves_hp,
                         learning_rate = learning_rate_hp,
                         random_state = 0,is_unbalance=True)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:35:35,282] A new study created in memory with name: no-name-7d987c2c-f5d4-4046-9e4a-25e035a1b268
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:36,123] Trial 0 finished with value: 0.768641930835735 and parameters: {'n_estimators': 698, 'max_depth': 493, 'min_child_samples': 31, 'num_leaves': 15, 'learning_rate': 0.0319969074815888}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:37,043] Trial 1 finished with value: 0.7244336375280179 and parameters: {'n_estimators': 322, 'max_depth': 481, 'min_child_samples': 35, 'num_leaves': 85, 'learning_rate': 0.0013544021834877055}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:37,192] Trial 2 finished with value: 0.570995437079731 and parameters: {'n_estimators': 100, 'max_depth': 466, 'min_child_samples': 42, 'num_leaves': 27, 'learning_rate': 5.169171710124146}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:39,273] Trial 3 finished with value: 0.7607268651937239 and parameters: {'n_estimators': 773, 'max_depth': 340, 'min_child_samples': 23, 'num_leaves': 243, 'learning_rate': 0.008200146117155251}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:41,859] Trial 4 finished with value: 0.7189201088696765 and parameters: {'n_estimators': 913, 'max_depth': 12, 'min_child_samples': 22, 'num_leaves': 215, 'learning_rate': 4.116453013217828e-05}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:42,324] Trial 5 finished with value: 0.6673971341658662 and parameters: {'n_estimators': 640, 'max_depth': 187, 'min_child_samples': 85, 'num_leaves': 138, 'learning_rate': 5.65851300015814e-05}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:43,208] Trial 6 finished with value: 0.6832772974703811 and parameters: {'n_estimators': 891, 'max_depth': 147, 'min_child_samples': 59, 'num_leaves': 69, 'learning_rate': 2.7616111821589024e-05}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:44,959] Trial 7 finished with value: 0.715537944284342 and parameters: {'n_estimators': 984, 'max_depth': 157, 'min_child_samples': 34, 'num_leaves': 44, 'learning_rate': 0.0002304492043603052}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:45,090] Trial 8 finished with value: 0.6640950208133205 and parameters: {'n_estimators': 155, 'max_depth': 215, 'min_child_samples': 95, 'num_leaves': 107, 'learning_rate': 0.00011530432320924513}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:45,972] Trial 9 finished with value: 0.7607969100224145 and parameters: {'n_estimators': 401, 'max_depth': 344, 'min_child_samples': 41, 'num_leaves': 16, 'learning_rate': 0.05893595990200804}. Best is trial 0 with value: 0.768641930835735.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:46,594] Trial 10 finished with value: 0.7687820204931155 and parameters: {'n_estimators': 592, 'max_depth': 370, 'min_child_samples': 11, 'num_leaves': 164, 'learning_rate': 0.43487471270883754}. Best is trial 10 with value: 0.7687820204931155.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:47,129] Trial 11 finished with value: 0.7717639289145052 and parameters: {'n_estimators': 642, 'max_depth': 383, 'min_child_samples': 10, 'num_leaves': 169, 'learning_rate': 0.4632476338916818}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:47,289] Trial 12 finished with value: 0.5897274255523536 and parameters: {'n_estimators': 505, 'max_depth': 360, 'min_child_samples': 10, 'num_leaves': 161, 'learning_rate': 1.7514931102412117}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:47,755] Trial 13 finished with value: 0.7682716938840859 and parameters: {'n_estimators': 536, 'max_depth': 398, 'min_child_samples': 11, 'num_leaves': 170, 'learning_rate': 0.4971995527814464}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:48,441] Trial 14 finished with value: 0.7610070445084853 and parameters: {'n_estimators': 584, 'max_depth': 270, 'min_child_samples': 60, 'num_leaves': 192, 'learning_rate': 0.20559578872495454}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:48,604] Trial 15 finished with value: 0.48046749919948767 and parameters: {'n_estimators': 772, 'max_depth': 285, 'min_child_samples': 50, 'num_leaves': 132, 'learning_rate': 9.138777920196356}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:49,015] Trial 16 finished with value: 0.7590157700928595 and parameters: {'n_estimators': 384, 'max_depth': 416, 'min_child_samples': 71, 'num_leaves': 205, 'learning_rate': 0.46635329635544837}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:50,545] Trial 17 finished with value: 0.7610670829330772 and parameters: {'n_estimators': 264, 'max_depth': 429, 'min_child_samples': 20, 'num_leaves': 256, 'learning_rate': 0.012031389646729007}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:35:51,350] Trial 18 finished with value: 0.5421669868715978 and parameters: {'n_estimators': 447, 'max_depth': 305, 'min_child_samples': 10, 'num_leaves': 167, 'learning_rate': 1.7945423456800222}. Best is trial 11 with value: 0.7717639289145052.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15

# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:36:30,476] Trial 44 finished with value: 0.7365113672750561 and parameters: {'n_estimators': 96, 'max_depth': 200, 'min_child_samples': 23, 'num_leaves': 81, 'learning_rate': 1.009070804204788}. Best is trial 42 with value: 0.7797890650016011.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:36:31,272] Trial 45 finished with value: 0.7707532821005443 and parameters: {'n_estimators': 426, 'max_depth': 277, 'min_child_samples': 14, 'num_leaves': 115, 'learning_rate': 0.25514443961706224}. Best is trial 42 with value: 0.7797890650016011.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:36:31,989] Trial 46 finished with value: 0.7579150656420108 and parameters: {'n_estimators': 177, 'max_depth': 246, 'min_child_samples': 36, 'num_leaves': 104, 'learning_rate': 0.0685823446440191}. Best is trial 42 with value: 0.7797890650016011.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:36:33,761] Trial 47 finished with value: 0.77986911623439 and parameters: {'n_estimators': 300, 'max_depth': 468, 'min_child_samples': 13, 'num_leaves': 125, 'learning_rate': 0.009361313082003686}. Best is trial 47 with value: 0.77986911623439.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:36:33,853] Trial 48 finished with value: 0.6649455651617036 and parameters: {'n_estimators': 238, 'max_depth': 362, 'min_child_samples': 99, 'num_leaves': 2, 'learning_rate': 0.006627818632873763}. Best is trial 47 with value: 0.77986911623439.
# /tmp/ipykernel_2490244/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:36:35,092] Trial 49 finished with value: 0.7868335734870318 and parameters: {'n_estimators': 308, 'max_depth': 115, 'min_child_samples': 13, 'num_leaves': 81, 'learning_rate': 0.019937858608472442}. Best is trial 49 with value: 0.7868335734870318.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))


# Best trial: {'n_estimators': 308, 'max_depth': 115, 'min_child_samples': 13, 'num_leaves': 81, 'learning_rate': 0.019937858608472442}
#   Value: 0.7868335734870318
# Out:
# Best trial: {'n_estimators': 308, 'max_depth': 115, 'min_child_samples': 13, 'num_leaves': 81, 'learning_rate': 0.019937858608472442}
#   Value: 0.7868335734870318

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LGBMClassifier(**{'n_estimators': 308, 'max_depth': 115, 'min_child_samples': 13, 'num_leaves': 81, 'learning_rate': 0.019937858608472442}, random_state = 0,is_unbalance=True )
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.747003745318352

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve LGBM (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       356
#            1       0.56      0.47      0.51       135
#
#     accuracy                           0.75       491
#    macro avg       0.68      0.66      0.67       491
# weighted avg       0.74      0.75      0.74       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#     Value                     Feature
# 0    1538                      minute
# 1    1312  activity_inf_unknown_count
# 2    1262  activity_inf_walking_count
# 3    1125     audio_inf_silence_count
# 4    1058       audio_inf_voice_count
# ..    ...                         ...
# 81      0                 grade_B_min
# 82      0                     grade_B
# 83      0           effort_Class 2 no
# 84      0        challenge_Class 2 no
# 85      0     audio_inf_unknown_count
#
# [86 rows x 2 columns]

# %% [markdown]
# ## Log reg

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 86), (1473,), (491, 86), (491,), (491, 86), (491,))

# %%
sc = StandardScaler()
sc = sc.fit(df_train_x)

df_train_x_sc = sc.transform(df_train_x)
df_val_x_sc = sc.transform(df_val_x)
df_test_x_sc = sc.transform(df_test_x)

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.0001, 100)
  
  
  model = LogisticRegression(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:37:26,477] A new study created in memory with name: no-name-d5e7589d-efc5-4d76-a6fa-e648f88fd9bd
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:27,299] Trial 0 finished with value: 0.6830371437720141 and parameters: {'C': 86.6622144156259}. Best is trial 0 with value: 0.6830371437720141.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:27,539] Trial 1 finished with value: 0.6823567082933077 and parameters: {'C': 67.94576549646057}. Best is trial 0 with value: 0.6830371437720141.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:27,773] Trial 2 finished with value: 0.6829370797310278 and parameters: {'C': 99.36567241396068}. Best is trial 0 with value: 0.6830371437720141.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:28,020] Trial 3 finished with value: 0.6820565161703489 and parameters: {'C': 0.6197393878185586}. Best is trial 0 with value: 0.6830371437720141.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:28,261] Trial 4 finished with value: 0.6827369516490553 and parameters: {'C': 71.81572641902765}. Best is trial 0 with value: 0.6830371437720141.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:28,511] Trial 5 finished with value: 0.683597502401537 and parameters: {'C': 43.06041380681798}. Best is trial 5 with value: 0.683597502401537.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:28,748] Trial 6 finished with value: 0.6827769772654498 and parameters: {'C': 14.483885060643242}. Best is trial 5 with value: 0.683597502401537.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:28,988] Trial 7 finished with value: 0.6824367595260966 and parameters: {'C': 94.27479093991644}. Best is trial 5 with value: 0.683597502401537.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:29,237] Trial 8 finished with value: 0.6828570284982388 and parameters: {'C': 79.86452338136537}. Best is trial 5 with value: 0.683597502401537.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:29,474] Trial 9 finished with value: 0.6830171309638168 and parameters: {'C': 31.50661852330098}. Best is trial 5 with value: 0.683597502401537.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:37:29,723] Trial 10 finished with value: 0.6834173871277617 and parameters: {'C': 49.49577683932287}. Best is trial 5 with value: 0.683597502401537.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15
. Best is trial 5 with value: 0.683597502401537.
# [I 2022-11-25 15:37:31,966] Trial 44 finished with value: 0.6829971181556196 and parameters: {'C': 67.0474157393611}. Best is trial 5 with value: 0.683597502401537.
# [I 2022-11-25 15:37:32,035] Trial 45 finished with value: 0.6824367595260967 and parameters: {'C': 45.76033608971773}. Best is trial 5 with value: 0.683597502401537.
# [I 2022-11-25 15:37:32,101] Trial 46 finished with value: 0.6830571565802113 and parameters: {'C': 62.73749400707031}. Best is trial 5 with value: 0.683597502401537.
# [I 2022-11-25 15:37:32,177] Trial 47 finished with value: 0.6829771053474225 and parameters: {'C': 52.577930037439494}. Best is trial 5 with value: 0.683597502401537.
# [I 2022-11-25 15:37:32,242] Trial 48 finished with value: 0.6826368876080692 and parameters: {'C': 69.0734535497897}. Best is trial 5 with value: 0.683597502401537.
# [I 2022-11-25 15:37:32,304] Trial 49 finished with value: 0.6824167467178994 and parameters: {'C': 58.214482464528984}. Best is trial 5 with value: 0.683597502401537.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'C': 43.06041380681798}
#   Value: 0.683597502401537
# Out:
# Best trial: {'C': 43.06041380681798}
#   Value: 0.683597502401537

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LogisticRegression(**{'C': 43.06041380681798}, random_state = 0,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.7044943820224718

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Logistic Regression (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.62      0.72       356
#            1       0.41      0.70      0.52       135
#
#     accuracy                           0.64       491
#    macro avg       0.63      0.66      0.62       491
# weighted avg       0.72      0.64      0.66       491

# %% [markdown]
# ## SVM

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.001, 100)
  
  
  model = SVC(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",probability = True)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:38:03,855] A new study created in memory with name: no-name-77a4c0c6-ef06-4f06-8bc9-491510ded958
# [I 2022-11-25 15:38:04,341] Trial 0 finished with value: 0.7203610310598783 and parameters: {'C': 79.61661905005124}. Best is trial 0 with value: 0.7203610310598783.
# [I 2022-11-25 15:38:04,814] Trial 1 finished with value: 0.7244036183157221 and parameters: {'C': 57.593321822288196}. Best is trial 1 with value: 0.7244036183157221.
# [I 2022-11-25 15:38:05,287] Trial 2 finished with value: 0.7246837976304835 and parameters: {'C': 56.262081368078064}. Best is trial 2 with value: 0.7246837976304835.
# [I 2022-11-25 15:38:05,758] Trial 3 finished with value: 0.7255043227665706 and parameters: {'C': 53.36486757248339}. Best is trial 3 with value: 0.7255043227665706.
. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:15,508] Trial 26 finished with value: 0.7388828850464295 and parameters: {'C': 14.126466246815209}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:15,966] Trial 27 finished with value: 0.7278258085174512 and parameters: {'C': 45.26651907322407}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:16,442] Trial 28 finished with value: 0.7317883445405059 and parameters: {'C': 31.549177469652168}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:16,870] Trial 29 finished with value: 0.7389729426833173 and parameters: {'C': 10.215645151409944}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:17,329] Trial 30 finished with value: 0.7376320845341018 and parameters: {'C': 21.128328649983096}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:17,759] Trial 31 finished with value: 0.7388528658341339 and parameters: {'C': 9.87541699571044}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:18,190] Trial 32 finished with value: 0.7389429234710214 and parameters: {'C': 11.919029062365139}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:18,560] Trial 33 finished with value: 0.73699167467179 and parameters: {'C': 4.818615325913507}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:18,994] Trial 34 finished with value: 0.7384926352865834 and parameters: {'C': 18.84097506127077}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:19,462] Trial 35 finished with value: 0.7240133685558758 and parameters: {'C': 61.84433163409429}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:19,914] Trial 36 finished with value: 0.732368715978226 and parameters: {'C': 30.363120828981327}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:20,345] Trial 37 finished with value: 0.7370717259045789 and parameters: {'C': 22.283158058653278}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:20,802] Trial 38 finished with value: 0.7285562760166506 and parameters: {'C': 41.886454890679694}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:21,283] Trial 39 finished with value: 0.718299711815562 and parameters: {'C': 93.70530400587587}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:21,749] Trial 40 finished with value: 0.7238732788984952 and parameters: {'C': 62.64389785271656}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:22,159] Trial 41 finished with value: 0.738712776176753 and parameters: {'C': 11.356863274038336}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:22,573] Trial 42 finished with value: 0.7389729426833174 and parameters: {'C': 13.024484894806456}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:22,916] Trial 43 finished with value: 0.7321285622798592 and parameters: {'C': 3.4879029980166507}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:23,339] Trial 44 finished with value: 0.7390429875120077 and parameters: {'C': 15.86485480658623}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:23,767] Trial 45 finished with value: 0.7365814121037464 and parameters: {'C': 23.513297814418692}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:24,194] Trial 46 finished with value: 0.7386727505603586 and parameters: {'C': 17.570692284405247}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:24,571] Trial 47 finished with value: 0.7388428594300351 and parameters: {'C': 7.493572801732499}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:25,033] Trial 48 finished with value: 0.7349503682356707 and parameters: {'C': 25.713465081232826}. Best is trial 19 with value: 0.7392331091898815.
# [I 2022-11-25 15:38:25,458] Trial 49 finished with value: 0.7390029618956133 and parameters: {'C': 16.066115788035773}. Best is trial 19 with value: 0.7392331091898815.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'C': 13.843442800296756}
#   Value: 0.7392331091898815
# Out:
# Best trial: {'C': 13.843442800296756}
#   Value: 0.7392331091898815

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = SVC(**{'C': 13.843442800296756}, random_state = 0,class_weight="balanced",probability = True)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.7249271743653765

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Support Vector Machine (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78       356
#            1       0.46      0.56      0.51       135
#
#     accuracy                           0.70       491
#    macro avg       0.64      0.66      0.64       491
# weighted avg       0.72      0.70      0.71       491

# %% [markdown]
# ## Random forest

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 86), (1473,), (491, 86), (491,), (491, 86), (491,))

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 100)
  min_child_samples_hp = trial.suggest_int('min_samples_split', 10, 100)
  num_leaves_hp = trial.suggest_int('min_samples_leaf', 2, 256)
  
  
  model = RandomForestClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_samples_split = min_child_samples_hp,
                         min_samples_leaf = num_leaves_hp,
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:39:10,001] A new study created in memory with name: no-name-a60aba49-d9b6-4a13-a36b-d96c9ab94cc2
# [I 2022-11-25 15:39:12,525] Trial 0 finished with value: 0.6984269932756965 and parameters: {'n_estimators': 919, 'max_depth': 79, 'min_samples_split': 26, 'min_samples_leaf': 56}. Best is trial 0 with value: 0.6984269932756965.
# [I 2022-11-25 15:39:13,769] Trial 1 finished with value: 0.6926532981107908 and parameters: {'n_estimators': 315, 'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 52}. Best is trial 0 with value: 0.6984269932756965.
# [I 2022-11-25 15:39:18,147] Trial 2 finished with value: 0.6814161063080372 and parameters: {'n_estimators': 963, 'max_depth': 63, 'min_samples_split': 72, 'min_samples_leaf': 109}. Best is trial 0 with value: 0.6984269932756965.
# [I 2022-11-25 15:39:18,858] Trial 3 finished with value: 0.6787143772014088 and parameters: {'n_estimators': 181, 'max_depth': 78, 'min_samples_split': 62, 'min_samples_leaf': 139}. Best is trial 0 with value: 0.6984269932756965.
# [I 2022-11-25 15:39:19,328] Trial 4 finished with value: 0.7115654018571886 and parameters: {'n_estimators': 127, 'max_depth': 27, 'min_samples_split': 43, 'min_samples_leaf': 39}. Best is trial 4 with value: 0.7115654018571886.
# [I 2022-11-25 15:39:20,530] Trial 5 finished with value: 0.6813760806916427 and parameters: {'n_estimators': 311, 'max_depth': 96, 'min_samples_split': 100, 'min_samples_leaf': 118}. Best is trial 4 with value: 0.7115654018571886.
# [I 2022-11-25 15:39:22,788] Trial 6 finished with value: 0.6674671789945564 and parameters: {'n_estimators': 591, 'max_depth': 46, 'min_samples_split': 58, 'min_samples_leaf': 183}. Best is trial 4 with value: 0.7115654018571886.
# [I 2022-11-25 15:39:25,456] Trial 7 finished with value: 0.6691682676913223 and parameters: {'n_estimators': 808, 'max_depth': 62, 'min_samples_split': 57, 'min_samples_leaf': 243}. Best is trial 4 with value: 0.7115654018571886.
# [I 2022-11-25 15:39:25,841] Trial 8 finished with value: 0.67863432596862 and parameters: {'n_estimators': 140, 'max_depth': 58, 'min_samples_split': 55, 'min_samples_leaf': 142}. Best is trial 4 with value: 0.7115654018571886.
# [I 2022-11-25 15:39:27,288] Trial 9 finished with value: 0.6762528017931475 and parameters: {'n_estimators': 310, 'max_depth': 94, 'min_samples_split': 68, 'min_samples_leaf': 148}. Best is trial 4 with value: 0.7115654018571886.
# [I 2022-11-25 15:39:30,195] Trial 10 finished with value: 0.7337195805315402 and parameters: {'n_estimators': 612, 'max_depth': 13, 'min_samples_split': 40, 'min_samples_leaf': 10}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:32,424] Trial 11 finished with value: 0.7317583253282101 and parameters: {'n_estimators': 562, 'max_depth': 11, 'min_samples_split': 36, 'min_samples_leaf': 8}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:34,566] Trial 12 finished with value: 0.729396813960935 and parameters: {'n_estimators': 606, 'max_depth': 13, 'min_samples_split': 34, 'min_samples_leaf': 14}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:37,266] Trial 13 finished with value: 0.7309378001921231 and parameters: {'n_estimators': 716, 'max_depth': 10, 'min_samples_split': 38, 'min_samples_leaf': 7}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:39,311] Trial 14 finished with value: 0.6916826769132245 and parameters: {'n_estimators': 458, 'max_depth': 38, 'min_samples_split': 11, 'min_samples_leaf': 80}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:41,680] Trial 15 finished with value: 0.6922430355427474 and parameters: {'n_estimators': 491, 'max_depth': 25, 'min_samples_split': 27, 'min_samples_leaf': 83}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:44,638] Trial 16 finished with value: 0.7213416586615434 and parameters: {'n_estimators': 733, 'max_depth': 40, 'min_samples_split': 83, 'min_samples_leaf': 6}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:46,499] Trial 17 finished with value: 0.7117255043227666 and parameters: {'n_estimators': 439, 'max_depth': 18, 'min_samples_split': 46, 'min_samples_leaf': 34}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:49,487] Trial 18 finished with value: 0.667747358309318 and parameters: {'n_estimators': 634, 'max_depth': 35, 'min_samples_split': 21, 'min_samples_leaf': 184}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:53,189] Trial 19 finished with value: 0.6904819084213896 and parameters: {'n_estimators': 826, 'max_depth': 51, 'min_samples_split': 44, 'min_samples_leaf': 82}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:54,729] Trial 20 finished with value: 0.666926833173231 and parameters: {'n_estimators': 394, 'max_depth': 31, 'min_samples_split': 32, 'min_samples_leaf': 241}. Best is trial 10 with value: 0.7337195805315402.
# [I 2022-11-25 15:39:57,909] Trial 21 finished with value: 0.7358509446045469 and parameters: {'n_estimators': 717, 'max_depth': 11, 'min_samples_split': 39, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.7358509446045469.
# [I 2022-11-25 15:40:00,787] Trial 22 finished with value: 0.7163484630163304 and parameters: {'n_estimators': 702, 'max_depth': 18, 'min_samples_split': 47, 'min_samples_leaf': 28}. Best is trial 21 with value: 0.7358509446045469.
# [I 2022-11-25 15:40:02,766] Trial 23 finished with value: 0.6935438680755683 and parameters: {'n_estimators': 527, 'max_depth': 10, 'min_samples_split': 37, 'min_samples_leaf': 61}. Best is trial 21 with value: 0.7358509446045469.
# [I 2022-11-25 15:40:05,558] Trial 24 finished with value: 0.7569544508485431 and parameters: {'n_estimators': 809, 'max_depth': 19, 'min_samples_split': 19, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:09,221] Trial 25 finished with value: 0.7144272334293948 and parameters: {'n_estimators': 852, 'max_depth': 20, 'min_samples_split': 20, 'min_samples_leaf': 33}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:11,004] Trial 26 finished with value: 0.7508105187319883 and parameters: {'n_estimators': 650, 'max_depth': 19, 'min_samples_split': 27, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:14,486] Trial 27 finished with value: 0.6956352065321806 and parameters: {'n_estimators': 775, 'max_depth': 30, 'min_samples_split': 27, 'min_samples_leaf': 64}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:18,001] Trial 28 finished with value: 0.7206111911623438 and parameters: {'n_estimators': 901, 'max_depth': 23, 'min_samples_split': 10, 'min_samples_leaf': 24}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:22,804] Trial 29 finished with value: 0.6992575248158822 and parameters: {'n_estimators': 986, 'max_depth': 41, 'min_samples_split': 19, 'min_samples_leaf': 52}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:25,408] Trial 30 finished with value: 0.6857588856868395 and parameters: {'n_estimators': 667, 'max_depth': 72, 'min_samples_split': 28, 'min_samples_leaf': 102}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:27,760] Trial 31 finished with value: 0.7338496637848223 and parameters: {'n_estimators': 767, 'max_depth': 17, 'min_samples_split': 50, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:30,928] Trial 32 finished with value: 0.7060018411783541 and parameters: {'n_estimators': 891, 'max_depth': 18, 'min_samples_split': 24, 'min_samples_leaf': 42}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:33,154] Trial 33 finished with value: 0.7331492154979187 and parameters: {'n_estimators': 764, 'max_depth': 32, 'min_samples_split': 49, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:34,988] Trial 34 finished with value: 0.7221721902017292 and parameters: {'n_estimators': 674, 'max_depth': 24, 'min_samples_split': 16, 'min_samples_leaf': 22}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:38,180] Trial 35 finished with value: 0.7034602145373039 and parameters: {'n_estimators': 922, 'max_depth': 18, 'min_samples_split': 51, 'min_samples_leaf': 46}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:40,694] Trial 36 finished with value: 0.7247138168427794 and parameters: {'n_estimators': 758, 'max_depth': 27, 'min_samples_split': 31, 'min_samples_leaf': 19}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:43,774] Trial 37 finished with value: 0.6944344380403459 and parameters: {'n_estimators': 852, 'max_depth': 45, 'min_samples_split': 52, 'min_samples_leaf': 65}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:46,060] Trial 38 finished with value: 0.7273755203330131 and parameters: {'n_estimators': 655, 'max_depth': 15, 'min_samples_split': 66, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:46,276] Trial 39 finished with value: 0.6720501120717259 and parameters: {'n_estimators': 59, 'max_depth': 22, 'min_samples_split': 81, 'min_samples_leaf': 171}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:49,046] Trial 40 finished with value: 0.7117855427473583 and parameters: {'n_estimators': 797, 'max_depth': 69, 'min_samples_split': 41, 'min_samples_leaf': 35}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:50,524] Trial 41 finished with value: 0.7247638488632725 and parameters: {'n_estimators': 565, 'max_depth': 15, 'min_samples_split': 41, 'min_samples_leaf': 20}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:52,671] Trial 42 finished with value: 0.7188600704450849 and parameters: {'n_estimators': 617, 'max_depth': 15, 'min_samples_split': 62, 'min_samples_leaf': 17}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:54,977] Trial 43 finished with value: 0.7472382324687799 and parameters: {'n_estimators': 721, 'max_depth': 84, 'min_samples_split': 32, 'min_samples_leaf': 2}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:40:57,486] Trial 44 finished with value: 0.7009386007044509 and parameters: {'n_estimators': 705, 'max_depth': 83, 'min_samples_split': 23, 'min_samples_leaf': 48}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:41:00,461] Trial 45 finished with value: 0.7168888088376562 and parameters: {'n_estimators': 848, 'max_depth': 84, 'min_samples_split': 15, 'min_samples_leaf': 27}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:41:02,438] Trial 46 finished with value: 0.7296769932756964 and parameters: {'n_estimators': 738, 'max_depth': 93, 'min_samples_split': 35, 'min_samples_leaf': 14}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:41:05,874] Trial 47 finished with value: 0.7432256644252321 and parameters: {'n_estimators': 946, 'max_depth': 63, 'min_samples_split': 32, 'min_samples_leaf': 3}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:41:09,387] Trial 48 finished with value: 0.66758725584374 and parameters: {'n_estimators': 959, 'max_depth': 100, 'min_samples_split': 30, 'min_samples_leaf': 229}. Best is trial 24 with value: 0.7569544508485431.
# [I 2022-11-25 15:41:13,235] Trial 49 finished with value: 0.7070224943964136 and parameters: {'n_estimators': 935, 'max_depth': 56, 'min_samples_split': 17, 'min_samples_leaf': 40}. Best is trial 24 with value: 0.7569544508485431.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'n_estimators': 809, 'max_depth': 19, 'min_samples_split': 19, 'min_samples_leaf': 3}
#   Value: 0.7569544508485431
# Out:
# Best trial: {'n_estimators': 809, 'max_depth': 19, 'min_samples_split': 19, 'min_samples_leaf': 3}
#   Value: 0.7569544508485431

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = RandomForestClassifier(**{'n_estimators': 809, 'max_depth': 19, 'min_samples_split': 19, 'min_samples_leaf': 3},random_state = 0 ,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.7334789846025801

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Random Forest (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       356
#            1       0.51      0.47      0.49       135
#
#     accuracy                           0.73       491
#    macro avg       0.66      0.65      0.65       491
# weighted avg       0.73      0.73      0.73       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#        Value                        Feature
# 0   0.053288     activity_inf_unknown_count
# 1   0.038160                            day
# 2   0.038018                     weeknumber
# 3   0.037277  activity_inf_stationary_count
# 4   0.037016     activity_inf_walking_count
# ..       ...                            ...
# 81  0.000000                    grade_C_min
# 82  0.000000                        grade_C
# 83  0.000000                    grade_B_min
# 84  0.000000              effort_Class 2 no
# 85  0.000000        audio_inf_unknown_count
#
# [86 rows x 2 columns]

# %% [markdown]
# ## End
