# %%
### importing libraries

from datetime import datetime,timedelta
from collections import defaultdict
from tqdm import tqdm

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import json
import os
import gc

from lightgbm import LGBMClassifier
import optuna

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,roc_curve,confusion_matrix,accuracy_score,auc,classification_report

# %% [markdown]
# ## load dataset

# %%
df = pd.read_csv('./data/sensing_data_0.5.csv')
df.head()
# Out:
#   user_id            date_time  activity_inf_stationary_count  \
# 0     u17  2013-03-28 15:08:00                           3664
# 1     u17  2013-03-30 16:06:00                           4045
# 2     u17  2013-04-11 16:53:00                           3640
# 3     u17  2013-04-14 15:33:00                           4014
# 4     u17  2013-04-15 14:07:00                           3653
#
#    activity_inf_walking_count  activity_inf_running_count  \
# 0                         315                          62
# 1                          18                           0
# 2                         362                          15
# 3                         112                           0
# 4                         269                          75
#
#    activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 0                          65                              5
# 1                          16                              9
# 2                          78                              5
# 3                          22                              6
# 4                         129                             11
#
#    app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 0                                5                                9
# 1                                9                               17
# 2                                5                                6
# 3                                6                                6
# 4                               10                               12
#
#    app_usage_baseActivity_numActivities  ...  year  month  day  hours  minute  \
# 0                                   156  ...  2013      3   28     15       8
# 1                                   237  ...  2013      3   30     16       6
# 2                                   180  ...  2013      4   11     16      53
# 3                                   434  ...  2013      4   14     15      33
# 4                                   377  ...  2013      4   15     14       7
#
#    weekday  weeknumber  label_source  rating  stress_label
# 0      Thu          12    stress_ema       1             0
# 1      Sat          12    stress_ema       2             1
# 2      Thu          14    stress_ema       3             1
# 3      Sun          14    stress_ema       3             1
# 4      Mon          15    stress_ema       3             1
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2455 entries, 0 to 2454
# Data columns (total 38 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   user_id                               2455 non-null   object
#  1   date_time                             2455 non-null   object
#  2   activity_inf_stationary_count         2455 non-null   int64
#  3   activity_inf_walking_count            2455 non-null   int64
#  4   activity_inf_running_count            2455 non-null   int64
#  5   activity_inf_unknown_count            2455 non-null   int64
#  6   app_usage_baseActivity_mClass         2455 non-null   int64
#  7   app_usage_baseActivity_mPackage       2455 non-null   int64
#  8   app_usage_baseActivity_id_count       2455 non-null   int64
#  9   app_usage_baseActivity_numActivities  2455 non-null   int64
#  10  app_usage_baseActivity_numRunning     2455 non-null   int64
#  11  app_usage_topActivity_mClass          2455 non-null   int64
#  12  app_usage_topActivity_mPackage        2455 non-null   int64
#  13  audio_inf_silence_count               2455 non-null   int64
#  14  audio_inf_voice_count                 2455 non-null   int64
#  15  audio_inf_noise_count                 2455 non-null   int64
#  16  audio_inf_unknown_count               2455 non-null   int64
#  17  conversation_hours                    2455 non-null   int64
#  18  conversation_minutes                  2455 non-null   int64
#  19  dark_hours                            2455 non-null   int64
#  20  dark_minutes                          2455 non-null   int64
#  21  dark_seconds                          2455 non-null   int64
#  22  phonecharge_hours                     2455 non-null   int64
#  23  phonecharge_minutes                   2455 non-null   int64
#  24  phonecharge_seconds                   2455 non-null   int64
#  25  phonelock_hours                       2455 non-null   int64
#  26  phonelock_minutes                     2455 non-null   int64
#  27  phonelock_seconds                     2455 non-null   int64
#  28  year                                  2455 non-null   int64
#  29  month                                 2455 non-null   int64
#  30  day                                   2455 non-null   int64
#  31  hours                                 2455 non-null   int64
#  32  minute                                2455 non-null   int64
#  33  weekday                               2455 non-null   object
#  34  weeknumber                            2455 non-null   int64
#  35  label_source                          2455 non-null   object
#  36  rating                                2455 non-null   int64
#  37  stress_label                          2455 non-null   int64
# dtypes: int64(34), object(4)
# memory usage: 729.0+ KB

# %%
df.describe()
# Out:
#        activity_inf_stationary_count  activity_inf_walking_count  \
# count                    2455.000000                 2455.000000
# mean                     4376.148676                  303.131976
# std                      3530.497803                  471.641989
# min                         0.000000                    0.000000
# 25%                      3398.500000                   91.000000
# 50%                      3744.000000                  186.000000
# 75%                      3971.000000                  314.000000
# max                     20949.000000                 5010.000000
#
#        activity_inf_running_count  activity_inf_unknown_count  \
# count                 2455.000000                 2455.000000
# mean                    77.894501                  189.774745
# std                    137.610712                  421.146866
# min                      0.000000                    0.000000
# 25%                      1.000000                   26.000000
# 50%                     28.000000                   62.000000
# 75%                     92.500000                  159.000000
# max                   2051.000000                 6594.000000
#
#        app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# count                    2455.000000                      2455.000000
# mean                       14.379226                        13.268024
# std                         9.087323                         8.148470
# min                         0.000000                         0.000000
# 25%                         8.000000                         8.000000
# 50%                        13.000000                        12.000000
# 75%                        19.000000                        17.000000
# max                        62.000000                        57.000000
#
#        app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# count                      2455.000000                           2455.000000
# mean                         17.239919                            594.028513
# std                          10.715056                            636.876830
# min                           0.000000                              0.000000
# 25%                          10.000000                            212.000000
# 50%                          16.000000                            436.000000
# 75%                          22.000000                            726.500000
# max                          78.000000                           4668.000000
#
#        app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# count                        2455.000000                   2455.000000  ...
# mean                          343.393483                     16.788187  ...
# std                           241.768032                     10.345968  ...
# min                             0.000000                      0.000000  ...
# 25%                           144.000000                     10.000000  ...
# 50%                           293.000000                     16.000000  ...
# 75%                           501.000000                     22.000000  ...
# max                          1981.000000                     73.000000  ...
#
#        phonelock_minutes  phonelock_seconds    year        month          day  \
# count        2455.000000        2455.000000  2455.0  2455.000000  2455.000000
# mean          194.195112       11674.794297  2013.0     4.224847    15.397963
# std           158.246817        9502.244947     0.0     0.664591     9.455342
# min             0.000000           0.000000  2013.0     3.000000     1.000000
# 25%            68.000000        4113.500000  2013.0     4.000000     7.000000
# 50%           174.000000       10467.000000  2013.0     4.000000    15.000000
# 75%           305.000000       18326.500000  2013.0     5.000000    25.000000
# max           803.000000       48239.000000  2013.0     6.000000    31.000000
#
#              hours       minute   weeknumber       rating  stress_label
# count  2455.000000  2455.000000  2455.000000  2455.000000   2455.000000
# mean     14.274134    24.409369    15.600815     2.182077      0.291650
# std       6.510618    18.665454     2.711081     1.294401      0.454614
# min       0.000000     0.000000    12.000000     1.000000      0.000000
# 25%      11.000000     7.000000    13.000000     1.000000      0.000000
# 50%      15.000000    22.000000    15.000000     2.000000      0.000000
# 75%      19.000000    40.000000    18.000000     3.000000      1.000000
# max      23.000000    59.000000    22.000000     5.000000      1.000000
#
# [8 rows x 34 columns]

# %% [markdown]
# ## Dropping columns

# %%
df = df.sample(frac= 1,random_state=2022)
df
# Out:
#      user_id            date_time  activity_inf_stationary_count  \
# 2391     u33  2013-04-04 23:42:00                           3872
# 1383     u27  2013-04-15 21:00:00                           3604
# 962      u41  2013-04-08 22:47:00                           1589
# 1063     u39  2013-04-16 23:34:00                           3995
# 2292     u49  2013-05-16 19:11:00                           6924
# ...      ...                  ...                            ...
# 1713     u08  2013-03-26 19:04:00                              0
# 624      u36  2013-04-17 01:55:00                           3693
# 173      u51  2013-04-30 17:06:00                           3944
# 1244     u10  2013-04-08 21:04:00                           3774
# 893      u58  2013-04-02 18:04:00                           3741
#
#       activity_inf_walking_count  activity_inf_running_count  \
# 2391                         191                           0
# 1383                         203                           1
# 962                            1                           0
# 1063                          62                          13
# 2292                         415                          48
# ...                          ...                         ...
# 1713                           0                           0
# 624                          247                          75
# 173                           47                         118
# 1244                         182                          46
# 893                          231                          40
#
#       activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 2391                          32                             46
# 1383                         187                             11
# 962                            2                              3
# 1063                          58                              6
# 2292                          43                             17
# ...                          ...                            ...
# 1713                           0                             13
# 624                           74                             13
# 173                           13                              6
# 1244                          30                              9
# 893                           57                             14
#
#       app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 2391                               43                               46
# 1383                               10                               31
# 962                                 3                                3
# 1063                                6                                9
# 2292                               14                               17
# ...                               ...                              ...
# 1713                               11                               20
# 624                                11                               13
# 173                                 6                                8
# 1244                                9                               10
# 893                                13                               20
#
#       app_usage_baseActivity_numActivities  ...  year  month  day  hours  \
# 2391                                  4132  ...  2013      4    4     23
# 1383                                   372  ...  2013      4   15     21
# 962                                     70  ...  2013      4    8     22
# 1063                                   168  ...  2013      4   16     23
# 2292                                   694  ...  2013      5   16     19
# ...                                    ...  ...   ...    ...  ...    ...
# 1713                                   105  ...  2013      3   26     19
# 624                                    554  ...  2013      4   17      1
# 173                                    169  ...  2013      4   30     17
# 1244                                   422  ...  2013      4    8     21
# 893                                    414  ...  2013      4    2     18
#
#       minute  weekday  weeknumber  label_source  rating  stress_label
# 2391      42      Thu          13    stress_ema       1             0
# 1383       0      Mon          15    stress_ema       1             0
# 962       47      Mon          14    stress_ema       1             0
# 1063      34      Tue          15    stress_ema       1             0
# 2292      11      Thu          19    stress_ema       5             0
# ...      ...      ...         ...           ...     ...           ...
# 1713       4      Tue          12    stress_ema       2             1
# 624       55      Wed          15    stress_ema       2             1
# 173        6      Tue          17    stress_ema       3             1
# 1244       4      Mon          14    stress_ema       5             0
# 893        4      Tue          13    stress_ema       1             0
#
# [2455 rows x 38 columns]

# %%
df = df.drop(['user_id','date_time','year','label_source','rating'],axis=1)

df['stress_label'].value_counts()
# Out:
# 0    1739
# 1     716
# Name: stress_label, dtype: int64

# %%
df['weekday'].value_counts()
# Out:
# Wed    392
# Tue    385
# Thu    375
# Fri    373
# Mon    362
# Sun    330
# Sat    238
# Name: weekday, dtype: int64

# %%
weekday_map = {"Sat":0,"Sun":1,"Mon":2,"Tue":3,"Wed":4,"Thu":5,"Fri":6}

df['weekday'] = df['weekday'].map(weekday_map)

df['weekday'].value_counts()
# Out:
# 4    392
# 3    385
# 5    375
# 6    373
# 2    362
# 1    330
# 0    238
# Name: weekday, dtype: int64

# %%
df = df.reset_index(drop=True)
df
# Out:
#       activity_inf_stationary_count  activity_inf_walking_count  \
# 0                              3872                         191
# 1                              3604                         203
# 2                              1589                           1
# 3                              3995                          62
# 4                              6924                         415
# ...                             ...                         ...
# 2450                              0                           0
# 2451                           3693                         247
# 2452                           3944                          47
# 2453                           3774                         182
# 2454                           3741                         231
#
#       activity_inf_running_count  activity_inf_unknown_count  \
# 0                              0                          32
# 1                              1                         187
# 2                              0                           2
# 3                             13                          58
# 4                             48                          43
# ...                          ...                         ...
# 2450                           0                           0
# 2451                          75                          74
# 2452                         118                          13
# 2453                          46                          30
# 2454                          40                          57
#
#       app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# 0                                46                               43
# 1                                11                               10
# 2                                 3                                3
# 3                                 6                                6
# 4                                17                               14
# ...                             ...                              ...
# 2450                             13                               11
# 2451                             13                               11
# 2452                              6                                6
# 2453                              9                                9
# 2454                             14                               13
#
#       app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# 0                                  46                                  4132
# 1                                  31                                   372
# 2                                   3                                    70
# 3                                   9                                   168
# 4                                  17                                   694
# ...                               ...                                   ...
# 2450                               20                                   105
# 2451                               13                                   554
# 2452                                8                                   169
# 2453                               10                                   422
# 2454                               20                                   414
#
#       app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# 0                                   794                            50  ...
# 1                                   341                            14  ...
# 2                                    66                             5  ...
# 3                                   168                             6  ...
# 4                                   622                            17  ...
# ...                                 ...                           ...  ...
# 2450                                 99                            14  ...
# 2451                                516                            15  ...
# 2452                                169                             6  ...
# 2453                                409                            11  ...
# 2454                                384                            15  ...
#
#       phonelock_hours  phonelock_minutes  phonelock_seconds  month  day  \
# 0                   2                136               8179      4    4
# 1                   0                  0                  0      4   15
# 2                   0                  0                  0      4    8
# 3                   1                 86               5173      4   16
# 4                   2                170              10210      5   16
# ...               ...                ...                ...    ...  ...
# 2450                0                  0                  0      3   26
# 2451                2                170              10232      4   17
# 2452                7                461              27715      4   30
# 2453                6                397              23844      4    8
# 2454                2                168              10080      4    2
#
#       hours  minute  weekday  weeknumber  stress_label
# 0        23      42        5          13             0
# 1        21       0        2          15             0
# 2        22      47        2          14             0
# 3        23      34        3          15             0
# 4        19      11        5          19             0
# ...     ...     ...      ...         ...           ...
# 2450     19       4        3          12             1
# 2451      1      55        4          15             1
# 2452     17       6        3          17             1
# 2453     21       4        2          14             0
# 2454     18       4        3          13             0
#
# [2455 rows x 33 columns]

# %% [markdown]
# ## Train val split

# %%
df_train,df_val,df_test = df[:(len(df)*3)//5],df[(len(df)*3)//5:(len(df)*4)//5],df[(len(df)*4)//5:]

len(df_train),len(df_val),len(df_test)
# Out:
# (1473, 491, 491)

# %%
df_train[df_train.columns[-1]]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1468    0
# 1469    0
# 1470    0
# 1471    0
# 1472    0
# Name: stress_label, Length: 1473, dtype: int64

# %% [markdown]
# ## LGBM

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 500)
  min_child_samples_hp = trial.suggest_int('min_child_samples', 10, 100)
  num_leaves_hp = trial.suggest_int('num_leaves', 2, 256)
  learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
  
  model = LGBMClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_child_samples = min_child_samples_hp,
                         num_leaves = num_leaves_hp,
                         learning_rate = learning_rate_hp,
                         random_state = 0,is_unbalance=True)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:14:20,390] A new study created in memory with name: no-name-009ac85d-3ccb-43d9-ac66-622382189375
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:21,195] Trial 0 finished with value: 0.7184898334934359 and parameters: {'n_estimators': 431, 'max_depth': 289, 'min_child_samples': 24, 'num_leaves': 45, 'learning_rate': 0.0973525371963429}. Best is trial 0 with value: 0.7184898334934359.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:21,301] Trial 1 finished with value: 0.47716538584694207 and parameters: {'n_estimators': 722, 'max_depth': 273, 'min_child_samples': 83, 'num_leaves': 123, 'learning_rate': 2.8031642854292254}. Best is trial 0 with value: 0.7184898334934359.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:21,402] Trial 2 finished with value: 0.46953049951969256 and parameters: {'n_estimators': 548, 'max_depth': 33, 'min_child_samples': 86, 'num_leaves': 54, 'learning_rate': 2.8643505159323346}. Best is trial 0 with value: 0.7184898334934359.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:21,872] Trial 3 finished with value: 0.6774835894972782 and parameters: {'n_estimators': 529, 'max_depth': 451, 'min_child_samples': 68, 'num_leaves': 254, 'learning_rate': 0.0010958382859005786}. Best is trial 0 with value: 0.7184898334934359.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:22,673] Trial 4 finished with value: 0.7193503842459174 and parameters: {'n_estimators': 587, 'max_depth': 253, 'min_child_samples': 31, 'num_leaves': 188, 'learning_rate': 0.0643325858008795}. Best is trial 4 with value: 0.7193503842459174.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:23,622] Trial 5 finished with value: 0.7265349823887287 and parameters: {'n_estimators': 226, 'max_depth': 38, 'min_child_samples': 12, 'num_leaves': 105, 'learning_rate': 0.05217062254834746}. Best is trial 5 with value: 0.7265349823887287.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14

# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:56,521] Trial 45 finished with value: 0.7006083893691962 and parameters: {'n_estimators': 458, 'max_depth': 175, 'min_child_samples': 74, 'num_leaves': 146, 'learning_rate': 0.004753309259153319}. Best is trial 26 with value: 0.7411743515850144.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:57,087] Trial 46 finished with value: 0.7125160102465578 and parameters: {'n_estimators': 392, 'max_depth': 217, 'min_child_samples': 35, 'num_leaves': 70, 'learning_rate': 0.03051505579031033}. Best is trial 26 with value: 0.7411743515850144.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:58,006] Trial 47 finished with value: 0.7077029298751201 and parameters: {'n_estimators': 248, 'max_depth': 266, 'min_child_samples': 10, 'num_leaves': 108, 'learning_rate': 0.0015190779868199302}. Best is trial 26 with value: 0.7411743515850144.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:58,847] Trial 48 finished with value: 0.7120156900416267 and parameters: {'n_estimators': 534, 'max_depth': 139, 'min_child_samples': 15, 'num_leaves': 53, 'learning_rate': 0.212604822222787}. Best is trial 26 with value: 0.7411743515850144.
# /tmp/ipykernel_2485372/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:14:59,022] Trial 49 finished with value: 0.7006584213896895 and parameters: {'n_estimators': 310, 'max_depth': 100, 'min_child_samples': 24, 'num_leaves': 90, 'learning_rate': 1.1294401547859227}. Best is trial 26 with value: 0.7411743515850144.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))


# Best trial: {'n_estimators': 436, 'max_depth': 133, 'min_child_samples': 12, 'num_leaves': 79, 'learning_rate': 0.011995657090104285}
#   Value: 0.7411743515850144
# Out:
# Best trial: {'n_estimators': 436, 'max_depth': 133, 'min_child_samples': 12, 'num_leaves': 79, 'learning_rate': 0.011995657090104285}
#   Value: 0.7411743515850144

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LGBMClassifier(**{'n_estimators': 436, 'max_depth': 133, 'min_child_samples': 12, 'num_leaves': 79, 'learning_rate': 0.011995657090104285}, random_state = 0,is_unbalance=True )
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.6715147732001666

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve LGBM (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       356
#            1       0.49      0.36      0.41       135
#
#     accuracy                           0.72       491
#    macro avg       0.63      0.61      0.61       491
# weighted avg       0.70      0.72      0.71       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#     Value                               Feature
# 0    2304                                minute
# 1    2168            activity_inf_unknown_count
# 2    2064               audio_inf_silence_count
# 3    2045                 audio_inf_voice_count
# 4    1927                                   day
# 5    1891                  conversation_minutes
# 6    1877            activity_inf_running_count
# 7    1794                 audio_inf_noise_count
# 8    1757         activity_inf_stationary_count
# 9    1724     app_usage_baseActivity_numRunning
# 10   1661  app_usage_baseActivity_numActivities
# 11   1421            activity_inf_walking_count
# 12   1411                     phonelock_minutes
# 13   1396                                 hours
# 14   1311                          dark_minutes
# 15   1103       app_usage_baseActivity_id_count
# 16    893                               weekday
# 17    874          app_usage_topActivity_mClass
# 18    828                            weeknumber
# 19    718                   phonecharge_minutes
# 20    580         app_usage_baseActivity_mClass
# 21    459       app_usage_baseActivity_mPackage
# 22    314                       phonelock_hours
# 23    308                            dark_hours
# 24    231                     phonecharge_hours
# 25    212                                 month
# 26    206                    conversation_hours
# 27    175                          dark_seconds
# 28    126                   phonecharge_seconds
# 29    121                     phonelock_seconds
# 30    109        app_usage_topActivity_mPackage
# 31      0               audio_inf_unknown_count

# %% [markdown]
# ## Log reg

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 32), (1473,), (491, 32), (491,), (491, 32), (491,))

# %%
sc = StandardScaler()
sc = sc.fit(df_train_x)

df_train_x_sc = sc.transform(df_train_x)
df_val_x_sc = sc.transform(df_val_x)
df_test_x_sc = sc.transform(df_test_x)

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.0001, 100)
  
  
  model = LogisticRegression(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:15:52,642] A new study created in memory with name: no-name-8ac84df8-25ff-4e4c-82f5-9e83fbe89c68
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:15:53,447] Trial 0 finished with value: 0.6632044508485431 and parameters: {'C': 61.11202879893383}. Best is trial 0 with value: 0.6632044508485431.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:15:53,695] Trial 1 finished with value: 0.6641250400256165 and parameters: {'C': 24.39098683837754}. Best is trial 1 with value: 0.6641250400256165.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:15:53,946] Trial 2 finished with value: 0.6641250400256163 and parameters: {'C': 35.49903872920223}. Best is trial 1 with value: 0.6641250400256165.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:15:54,200] Trial 3 finished with value: 0.6632244636567404 and parameters: {'C': 64.25559770368191}. Best is trial 1 with value: 0.6641250400256165.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:15:54,437] Trial 4 finished with value: 0.6635046429715017 and parameters: {'C': 53.40206897464836}. Best is trial 1 with value: 0.6641250400256165.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15
. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,077] Trial 33 finished with value: 0.6670068844060199 and parameters: {'C': 0.4509302811898529}. Best is trial 13 with value: 0.6671669868715978.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:15:57,128] Trial 34 finished with value: 0.6640249759846302 and parameters: {'C': 15.239966543062742}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,189] Trial 35 finished with value: 0.6641650656420108 and parameters: {'C': 20.304728434953695}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,241] Trial 36 finished with value: 0.6636847582452771 and parameters: {'C': 29.251214728790195}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,323] Trial 37 finished with value: 0.6643251681075888 and parameters: {'C': 6.56604145048062}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,403] Trial 38 finished with value: 0.664085014409222 and parameters: {'C': 14.079773340276082}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,454] Trial 39 finished with value: 0.6644852705731668 and parameters: {'C': 4.874357181332867}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,523] Trial 40 finished with value: 0.6640249759846303 and parameters: {'C': 23.620505680043795}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,566] Trial 41 finished with value: 0.6671269612552033 and parameters: {'C': 0.4647219735826751}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,627] Trial 42 finished with value: 0.6670669228306115 and parameters: {'C': 0.4618813178423839}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,700] Trial 43 finished with value: 0.6643651937239833 and parameters: {'C': 9.849344233646502}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,752] Trial 44 finished with value: 0.6641650656420108 and parameters: {'C': 5.502123800780737}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,807] Trial 45 finished with value: 0.6642851424911944 and parameters: {'C': 12.540888583792112}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,867] Trial 46 finished with value: 0.6633445405059238 and parameters: {'C': 70.93588418278088}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:57,952] Trial 47 finished with value: 0.6651256804354787 and parameters: {'C': 3.4361256395668915}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:58,019] Trial 48 finished with value: 0.6640850144092219 and parameters: {'C': 20.137394474159418}. Best is trial 13 with value: 0.6671669868715978.
# [I 2022-11-25 15:15:58,068] Trial 49 finished with value: 0.6629843099583734 and parameters: {'C': 58.85443583284582}. Best is trial 13 with value: 0.6671669868715978.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'C': 0.6192091255820088}
#   Value: 0.6671669868715978
# Out:
# Best trial: {'C': 0.6192091255820088}
#   Value: 0.6671669868715978

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LogisticRegression(**{'C': 0.6192091255820088}, random_state = 0,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.6454640033291719

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Logistic Regression (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.60      0.69       356
#            1       0.37      0.63      0.47       135
#
#     accuracy                           0.60       491
#    macro avg       0.59      0.61      0.58       491
# weighted avg       0.69      0.60      0.63       491

# %% [markdown]
# ## SVM

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.001, 100)
  
  
  model = SVC(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",probability = True)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:16:37,263] A new study created in memory with name: no-name-726f59ed-6a8b-4423-b1b2-792163082334
# [I 2022-11-25 15:16:37,678] Trial 0 finished with value: 0.6360770893371758 and parameters: {'C': 34.021714593783194}. Best is trial 0 with value: 0.6360770893371758.
# [I 2022-11-25 15:16:38,131] Trial 1 finished with value: 0.6294228306115914 and parameters: {'C': 48.93890158879394}. Best is trial 0 with value: 0.6360770893371758.
# [I 2022-11-25 15:16:38,446] Trial 2 finished with value: 0.6387187800192123 and parameters: {'C': 18.832736435722815}. Best is trial 2 with value: 0.6387187800192123.
# [I 2022-11-25 15:16:38,836] Trial 3 finished with value: 0.6362972302273455 and parameters: {'C': 33.57209795033793}. Best is trial 2 with value: 0.6387187800192123.
# [I 2022-11-25 15:16:39,299] Trial 4 finished with value: 0.6293427793788025 and parameters: {'C': 50.8257211128125}. Best is trial 2 with value: 0.6387187800192123.
# [I 2022-11-25 15:16:39,807] Trial 5 finished with value: 0.6263208453410182 and parameters: {'C': 60.890303170020964}. Best is trial 2 with value: 0.6387187800192123.
# [I 2022-11-25 15:16:40,324] Trial 6 finished with value: 0.6195765289785463 and parameters: {'C': 78.19542059085357}. Best is trial 2 with value: 0.6387187800192123.
# [I 2022-11-25 15:16:40,724] Trial 7 finished with value: 0.6357368715978226 and parameters: {'C': 34.25687178138914}. Best is trial 2 with value: 0.6387187800192123.
# [I 2022-11-25 15:16:41,233] Trial 8 finished with value: 0.6213176432917068 and parameters: {'C': 75.52953030613673}. Best is trial 2 with value: 0.6387187800192123.
# [I 2022-11-25 15:16:41,528] Trial 9 finished with value: 0.6403298110790906 and parameters: {'C': 15.057527391773313}. Best is trial 9 with value: 0.6403298110790906.
# [I 2022-11-25 15:16:41,785] Trial 10 finished with value: 0.6403698366954851 and parameters: {'C': 7.509746864430763}. Best is trial 10 with value: 0.6403698366954851.
# [I 2022-11-25 15:16:42,006] Trial 11 finished with value: 0.6420208933717579 and parameters: {'C': 1.007703621812448}. Best is trial 11 with value: 0.6420208933717579.
# [I 2022-11-25 15:16:42,246] Trial 12 finished with value: 0.6386687479987192 and parameters: {'C': 3.0080775944463167}. Best is trial 11 with value: 0.6420208933717579.
# [I 2022-11-25 15:16:42,464] Trial 13 finished with value: 0.6395393051552994 and parameters: {'C': 2.131245461709631}. Best is trial 11 with value: 0.6420208933717579.
# [I 2022-11-25 15:16:42,764] Trial 14 finished with value: 0.6403298110790906 and parameters: {'C': 14.370840693274307}. Best is trial 11 with value: 0.6420208933717579.
# [I 2022-11-25 15:16:43,305] Trial 15 finished with value: 0.614193083573487 and parameters: {'C': 99.8428057960204}. Best is trial 11 with value: 0.6420208933717579.
. Best is trial 18 with value: 0.6532380723663145.
# [I 2022-11-25 15:16:53,345] Trial 48 finished with value: 0.6395893371757926 and parameters: {'C': 17.71733928418229}. Best is trial 18 with value: 0.6532380723663145.
# [I 2022-11-25 15:16:53,865] Trial 49 finished with value: 0.6178654338776817 and parameters: {'C': 84.46503211113667}. Best is trial 18 with value: 0.6532380723663145.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'C': 0.24548137460953456}
#   Value: 0.6532380723663145
# Out:
# Best trial: {'C': 0.24548137460953456}
#   Value: 0.6532380723663145

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = SVC(**{'C': 0.24548137460953456}, random_state = 0,class_weight="balanced",probability = True)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.6325842696629214

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Support Vector Machine (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.59      0.68       356
#            1       0.36      0.61      0.45       135
#
#     accuracy                           0.59       491
#    macro avg       0.58      0.60      0.57       491
# weighted avg       0.68      0.59      0.62       491

# %% [markdown]
# ## Random forest

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 32), (1473,), (491, 32), (491,), (491, 32), (491,))

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 100)
  min_child_samples_hp = trial.suggest_int('min_samples_split', 10, 100)
  num_leaves_hp = trial.suggest_int('min_samples_leaf', 2, 256)
  
  
  model = RandomForestClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_samples_split = min_child_samples_hp,
                         min_samples_leaf = num_leaves_hp,
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:18:02,874] A new study created in memory with name: no-name-81801b19-5d95-4633-80f9-5d5da9727dcb
# [I 2022-11-25 15:18:04,227] Trial 0 finished with value: 0.6854987191802755 and parameters: {'n_estimators': 436, 'max_depth': 27, 'min_samples_split': 37, 'min_samples_leaf': 53}. Best is trial 0 with value: 0.6854987191802755.
# [I 2022-11-25 15:18:04,629] Trial 1 finished with value: 0.671329650976625 and parameters: {'n_estimators': 106, 'max_depth': 81, 'min_samples_split': 93, 'min_samples_leaf': 106}. Best is trial 0 with value: 0.6854987191802755.
# [I 2022-11-25 15:18:04,758] Trial 2 finished with value: 0.6502361511367274 and parameters: {'n_estimators': 55, 'max_depth': 81, 'min_samples_split': 72, 'min_samples_leaf': 112}. Best is trial 0 with value: 0.6854987191802755.
# [I 2022-11-25 15:18:06,153] Trial 3 finished with value: 0.6891810758885687 and parameters: {'n_estimators': 353, 'max_depth': 65, 'min_samples_split': 96, 'min_samples_leaf': 25}. Best is trial 3 with value: 0.6891810758885687.
# [I 2022-11-25 15:18:07,941] Trial 4 finished with value: 0.6907520813320525 and parameters: {'n_estimators': 611, 'max_depth': 57, 'min_samples_split': 79, 'min_samples_leaf': 9}. Best is trial 4 with value: 0.6907520813320525.
# [I 2022-11-25 15:18:09,958] Trial 5 finished with value: 0.6915025616394492 and parameters: {'n_estimators': 594, 'max_depth': 80, 'min_samples_split': 68, 'min_samples_leaf': 20}. Best is trial 5 with value: 0.6915025616394492.
# [I 2022-11-25 15:18:11,034] Trial 6 finished with value: 0.6638448607108549 and parameters: {'n_estimators': 461, 'max_depth': 30, 'min_samples_split': 34, 'min_samples_leaf': 197}. Best is trial 5 with value: 0.6915025616394492.
# [I 2022-11-25 15:18:14,529] Trial 7 finished with value: 0.6931936439321166 and parameters: {'n_estimators': 936, 'max_depth': 75, 'min_samples_split': 29, 'min_samples_leaf': 22}. Best is trial 7 with value: 0.6931936439321166.
# [I 2022-11-25 15:18:17,627] Trial 8 finished with value: 0.6593619916746718 and parameters: {'n_estimators': 893, 'max_depth': 24, 'min_samples_split': 28, 'min_samples_leaf': 174}. Best is trial 7 with value: 0.6931936439321166.
# [I 2022-11-25 15:18:21,018] Trial 9 finished with value: 0.6691082292667307 and parameters: {'n_estimators': 861, 'max_depth': 21, 'min_samples_split': 46, 'min_samples_leaf': 107}. Best is trial 7 with value: 0.6931936439321166.
# [I 2022-11-25 15:18:25,139] Trial 10 finished with value: 0.6578009926352866 and parameters: {'n_estimators': 987, 'max_depth': 95, 'min_samples_split': 18, 'min_samples_leaf': 249}. Best is trial 7 with value: 0.6931936439321166.
# [I 2022-11-25 15:18:27,754] Trial 11 finished with value: 0.6809758245276977 and parameters: {'n_estimators': 675, 'max_depth': 72, 'min_samples_split': 65, 'min_samples_leaf': 65}. Best is trial 7 with value: 0.6931936439321166.
# [I 2022-11-25 15:18:30,671] Trial 12 finished with value: 0.6860991034261928 and parameters: {'n_estimators': 739, 'max_depth': 45, 'min_samples_split': 54, 'min_samples_leaf': 46}. Best is trial 7 with value: 0.6931936439321166.
# [I 2022-11-25 15:18:31,335] Trial 13 finished with value: 0.7156380083253282 and parameters: {'n_estimators': 230, 'max_depth': 100, 'min_samples_split': 16, 'min_samples_leaf': 2}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:31,789] Trial 14 finished with value: 0.6793147614473263 and parameters: {'n_estimators': 229, 'max_depth': 94, 'min_samples_split': 10, 'min_samples_leaf': 73}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:32,420] Trial 15 finished with value: 0.7092939481268011 and parameters: {'n_estimators': 200, 'max_depth': 95, 'min_samples_split': 20, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:33,179] Trial 16 finished with value: 0.7038904899135447 and parameters: {'n_estimators': 250, 'max_depth': 100, 'min_samples_split': 13, 'min_samples_leaf': 5}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:33,985] Trial 17 finished with value: 0.6643852065321806 and parameters: {'n_estimators': 243, 'max_depth': 88, 'min_samples_split': 22, 'min_samples_leaf': 151}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:34,504] Trial 18 finished with value: 0.6832372718539866 and parameters: {'n_estimators': 149, 'max_depth': 42, 'min_samples_split': 44, 'min_samples_leaf': 70}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:35,968] Trial 19 finished with value: 0.6601424911943643 and parameters: {'n_estimators': 344, 'max_depth': 64, 'min_samples_split': 22, 'min_samples_leaf': 231}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:37,341] Trial 20 finished with value: 0.6771533781620238 and parameters: {'n_estimators': 368, 'max_depth': 12, 'min_samples_split': 40, 'min_samples_leaf': 86}. Best is trial 13 with value: 0.7156380083253282.
# [I 2022-11-25 15:18:38,157] Trial 21 finished with value: 0.7237632084534101 and parameters: {'n_estimators': 229, 'max_depth': 99, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:38,762] Trial 22 finished with value: 0.6844780659622157 and parameters: {'n_estimators': 175, 'max_depth': 100, 'min_samples_split': 10, 'min_samples_leaf': 35}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:39,591] Trial 23 finished with value: 0.7099643772014089 and parameters: {'n_estimators': 301, 'max_depth': 88, 'min_samples_split': 18, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:40,612] Trial 24 finished with value: 0.6858889689401216 and parameters: {'n_estimators': 306, 'max_depth': 89, 'min_samples_split': 26, 'min_samples_leaf': 44}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:42,462] Trial 25 finished with value: 0.6883805635606788 and parameters: {'n_estimators': 485, 'max_depth': 88, 'min_samples_split': 16, 'min_samples_leaf': 33}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:43,552] Trial 26 finished with value: 0.6651456932436759 and parameters: {'n_estimators': 288, 'max_depth': 87, 'min_samples_split': 52, 'min_samples_leaf': 135}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:45,058] Trial 27 finished with value: 0.6854486871597822 and parameters: {'n_estimators': 399, 'max_depth': 100, 'min_samples_split': 30, 'min_samples_leaf': 55}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:45,373] Trial 28 finished with value: 0.6768731988472623 and parameters: {'n_estimators': 112, 'max_depth': 71, 'min_samples_split': 16, 'min_samples_leaf': 87}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:47,039] Trial 29 finished with value: 0.7048911303234071 and parameters: {'n_estimators': 545, 'max_depth': 92, 'min_samples_split': 32, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:48,453] Trial 30 finished with value: 0.6857388728786424 and parameters: {'n_estimators': 433, 'max_depth': 83, 'min_samples_split': 39, 'min_samples_leaf': 53}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:48,949] Trial 31 finished with value: 0.7128962536023055 and parameters: {'n_estimators': 172, 'max_depth': 95, 'min_samples_split': 22, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:49,132] Trial 32 finished with value: 0.6966358469420428 and parameters: {'n_estimators': 64, 'max_depth': 94, 'min_samples_split': 24, 'min_samples_leaf': 18}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:49,414] Trial 33 finished with value: 0.6841578610310599 and parameters: {'n_estimators': 135, 'max_depth': 77, 'min_samples_split': 15, 'min_samples_leaf': 35}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:50,336] Trial 34 finished with value: 0.6978466218379762 and parameters: {'n_estimators': 308, 'max_depth': 85, 'min_samples_split': 20, 'min_samples_leaf': 17}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:50,505] Trial 35 finished with value: 0.6852585654819086 and parameters: {'n_estimators': 77, 'max_depth': 100, 'min_samples_split': 10, 'min_samples_leaf': 31}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:51,045] Trial 36 finished with value: 0.6967359109830291 and parameters: {'n_estimators': 188, 'max_depth': 64, 'min_samples_split': 25, 'min_samples_leaf': 14}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:51,963] Trial 37 finished with value: 0.6778538264489274 and parameters: {'n_estimators': 278, 'max_depth': 80, 'min_samples_split': 33, 'min_samples_leaf': 89}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:52,319] Trial 38 finished with value: 0.6887608069164265 and parameters: {'n_estimators': 119, 'max_depth': 55, 'min_samples_split': 88, 'min_samples_leaf': 25}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:53,484] Trial 39 finished with value: 0.703670349023375 and parameters: {'n_estimators': 352, 'max_depth': 91, 'min_samples_split': 37, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:54,316] Trial 40 finished with value: 0.6630043227665705 and parameters: {'n_estimators': 201, 'max_depth': 82, 'min_samples_split': 14, 'min_samples_leaf': 122}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:54,942] Trial 41 finished with value: 0.699687800192123 and parameters: {'n_estimators': 191, 'max_depth': 97, 'min_samples_split': 20, 'min_samples_leaf': 12}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:55,622] Trial 42 finished with value: 0.7073426993275698 and parameters: {'n_estimators': 232, 'max_depth': 95, 'min_samples_split': 19, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:56,070] Trial 43 finished with value: 0.69222302273455 and parameters: {'n_estimators': 159, 'max_depth': 91, 'min_samples_split': 63, 'min_samples_leaf': 21}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:57,182] Trial 44 finished with value: 0.6849883925712456 and parameters: {'n_estimators': 395, 'max_depth': 96, 'min_samples_split': 28, 'min_samples_leaf': 39}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:57,458] Trial 45 finished with value: 0.6899615754082613 and parameters: {'n_estimators': 94, 'max_depth': 85, 'min_samples_split': 82, 'min_samples_leaf': 24}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:58,261] Trial 46 finished with value: 0.6853186039065002 and parameters: {'n_estimators': 269, 'max_depth': 76, 'min_samples_split': 12, 'min_samples_leaf': 51}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:58,397] Trial 47 finished with value: 0.693523855267371 and parameters: {'n_estimators': 51, 'max_depth': 70, 'min_samples_split': 99, 'min_samples_leaf': 11}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:59,294] Trial 48 finished with value: 0.6837475984630162 and parameters: {'n_estimators': 324, 'max_depth': 92, 'min_samples_split': 18, 'min_samples_leaf': 59}. Best is trial 21 with value: 0.7237632084534101.
# [I 2022-11-25 15:18:59,934] Trial 49 finished with value: 0.6631243996157541 and parameters: {'n_estimators': 215, 'max_depth': 95, 'min_samples_split': 24, 'min_samples_leaf': 187}. Best is trial 21 with value: 0.7237632084534101.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'n_estimators': 229, 'max_depth': 99, 'min_samples_split': 10, 'min_samples_leaf': 4}
#   Value: 0.7237632084534101
# Out:
# Best trial: {'n_estimators': 229, 'max_depth': 99, 'min_samples_split': 10, 'min_samples_leaf': 4}
#   Value: 0.7237632084534101

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = RandomForestClassifier(**{'n_estimators': 229, 'max_depth': 99, 'min_samples_split': 10, 'min_samples_leaf': 4},random_state = 0 ,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.7001872659176029

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Random Forest (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82       356
#            1       0.50      0.39      0.44       135
#
#     accuracy                           0.73       491
#    macro avg       0.65      0.62      0.63       491
# weighted avg       0.71      0.73      0.71       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#        Value                               Feature
# 0   0.062915            activity_inf_unknown_count
# 1   0.062279         activity_inf_stationary_count
# 2   0.058352                                   day
# 3   0.053724                            weeknumber
# 4   0.045922               audio_inf_silence_count
# 5   0.045432     app_usage_baseActivity_numRunning
# 6   0.044055            activity_inf_walking_count
# 7   0.042985            activity_inf_running_count
# 8   0.040596                                minute
# 9   0.040303                 audio_inf_noise_count
# 10  0.039674                 audio_inf_voice_count
# 11  0.038949  app_usage_baseActivity_numActivities
# 12  0.037395                  conversation_minutes
# 13  0.030673       app_usage_baseActivity_id_count
# 14  0.030564          app_usage_topActivity_mClass
# 15  0.029013                     phonelock_seconds
# 16  0.026531                     phonelock_minutes
# 17  0.026156                                 hours
# 18  0.025041                          dark_seconds
# 19  0.024268        app_usage_topActivity_mPackage
# 20  0.023524       app_usage_baseActivity_mPackage
# 21  0.022536                          dark_minutes
# 22  0.021999         app_usage_baseActivity_mClass
# 23  0.021558                               weekday
# 24  0.021197                   phonecharge_seconds
# 25  0.020393                                 month
# 26  0.019542                   phonecharge_minutes
# 27  0.012162                       phonelock_hours
# 28  0.011390                    conversation_hours
# 29  0.011042                            dark_hours
# 30  0.009829                     phonecharge_hours
# 31  0.000000               audio_inf_unknown_count

# %% [markdown]
# ## End
