# %%
### importing libraries

from datetime import datetime,timedelta
from collections import defaultdict
from tqdm import tqdm

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import json
import os
import gc

from lightgbm import LGBMClassifier
import optuna

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,roc_curve,confusion_matrix,accuracy_score,auc,classification_report

# %% [markdown]
# ## load dataset

# %%
df = pd.read_csv('./data/sensing_data_1.csv')
df.head()
# Out:
#   user_id            date_time  activity_inf_stationary_count  \
# 0     u17  2013-03-28 15:08:00                           7712
# 1     u17  2013-03-30 16:06:00                           8090
# 2     u17  2013-04-11 16:53:00                           7808
# 3     u17  2013-04-14 15:33:00                           8181
# 4     u17  2013-04-15 14:07:00                           7413
#
#    activity_inf_walking_count  activity_inf_running_count  \
# 0                         372                          64
# 1                         103                           0
# 2                         362                          15
# 3                         117                           0
# 4                         572                          83
#
#    activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 0                         105                              6
# 1                          28                             10
# 2                          78                              7
# 3                          29                              6
# 4                         158                             15
#
#    app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 0                                6                               10
# 1                                9                               19
# 2                                6                                8
# 3                                6                                6
# 4                               14                               22
#
#    app_usage_baseActivity_numActivities  ...  year  month  day  hours  minute  \
# 0                                   295  ...  2013      3   28     15       8
# 1                                   456  ...  2013      3   30     16       6
# 2                                   372  ...  2013      4   11     16      53
# 3                                   895  ...  2013      4   14     15      33
# 4                                   608  ...  2013      4   15     14       7
#
#    weekday  weeknumber  label_source  rating  stress_label
# 0      Thu          12    stress_ema       1             0
# 1      Sat          12    stress_ema       2             1
# 2      Thu          14    stress_ema       3             1
# 3      Sun          14    stress_ema       3             1
# 4      Mon          15    stress_ema       3             1
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2455 entries, 0 to 2454
# Data columns (total 38 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   user_id                               2455 non-null   object
#  1   date_time                             2455 non-null   object
#  2   activity_inf_stationary_count         2455 non-null   int64
#  3   activity_inf_walking_count            2455 non-null   int64
#  4   activity_inf_running_count            2455 non-null   int64
#  5   activity_inf_unknown_count            2455 non-null   int64
#  6   app_usage_baseActivity_mClass         2455 non-null   int64
#  7   app_usage_baseActivity_mPackage       2455 non-null   int64
#  8   app_usage_baseActivity_id_count       2455 non-null   int64
#  9   app_usage_baseActivity_numActivities  2455 non-null   int64
#  10  app_usage_baseActivity_numRunning     2455 non-null   int64
#  11  app_usage_topActivity_mClass          2455 non-null   int64
#  12  app_usage_topActivity_mPackage        2455 non-null   int64
#  13  audio_inf_silence_count               2455 non-null   int64
#  14  audio_inf_voice_count                 2455 non-null   int64
#  15  audio_inf_noise_count                 2455 non-null   int64
#  16  audio_inf_unknown_count               2455 non-null   int64
#  17  conversation_hours                    2455 non-null   int64
#  18  conversation_minutes                  2455 non-null   int64
#  19  dark_hours                            2455 non-null   int64
#  20  dark_minutes                          2455 non-null   int64
#  21  dark_seconds                          2455 non-null   int64
#  22  phonecharge_hours                     2455 non-null   int64
#  23  phonecharge_minutes                   2455 non-null   int64
#  24  phonecharge_seconds                   2455 non-null   int64
#  25  phonelock_hours                       2455 non-null   int64
#  26  phonelock_minutes                     2455 non-null   int64
#  27  phonelock_seconds                     2455 non-null   int64
#  28  year                                  2455 non-null   int64
#  29  month                                 2455 non-null   int64
#  30  day                                   2455 non-null   int64
#  31  hours                                 2455 non-null   int64
#  32  minute                                2455 non-null   int64
#  33  weekday                               2455 non-null   object
#  34  weeknumber                            2455 non-null   int64
#  35  label_source                          2455 non-null   object
#  36  rating                                2455 non-null   int64
#  37  stress_label                          2455 non-null   int64
# dtypes: int64(34), object(4)
# memory usage: 729.0+ KB

# %%
df.describe()
# Out:
#        activity_inf_stationary_count  activity_inf_walking_count  \
# count                    2455.000000                 2455.000000
# mean                     8761.414257                  513.306721
# std                      6958.299961                  765.212702
# min                         0.000000                    0.000000
# 25%                      6984.500000                  179.000000
# 50%                      7574.000000                  317.000000
# 75%                      7916.500000                  488.000000
# max                     38597.000000                 7505.000000
#
#        activity_inf_running_count  activity_inf_unknown_count  \
# count                 2455.000000                 2455.000000
# mean                   127.201222                  338.782892
# std                    214.582839                  664.912629
# min                      0.000000                    0.000000
# 25%                      6.000000                   56.000000
# 50%                     51.000000                  115.000000
# 75%                    156.000000                  266.000000
# max                   3933.000000                 6825.000000
#
#        app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# count                    2455.000000                      2455.000000
# mean                       16.164155                        14.663544
# std                         9.526971                         8.406010
# min                         0.000000                         0.000000
# 25%                        10.000000                         9.000000
# 50%                        15.000000                        14.000000
# 75%                        21.000000                        19.000000
# max                        68.000000                        60.000000
#
#        app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# count                      2455.000000                           2455.000000
# mean                         21.452546                           1170.241548
# std                          12.847520                           1253.679425
# min                           0.000000                              0.000000
# 25%                          12.000000                            440.000000
# 50%                          20.000000                            863.000000
# 75%                          28.000000                           1422.000000
# max                         117.000000                           9325.000000
#
#        app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# count                        2455.000000                   2455.000000  ...
# mean                          675.301426                     19.388187  ...
# std                           470.465766                     11.392549  ...
# min                             0.000000                      0.000000  ...
# 25%                           285.000000                     12.000000  ...
# 50%                           584.000000                     18.000000  ...
# 75%                           997.000000                     26.000000  ...
# max                          3752.000000                     85.000000  ...
#
#        phonelock_minutes  phonelock_seconds    year        month          day  \
# count        2455.000000        2455.000000  2455.0  2455.000000  2455.000000
# mean          539.118534       32373.773523  2013.0     4.224847    15.397963
# std           333.060022       19988.204728     0.0     0.664591     9.455342
# min             0.000000           0.000000  2013.0     3.000000     1.000000
# 25%           275.000000       16501.000000  2013.0     4.000000     7.000000
# 50%           523.000000       31406.000000  2013.0     4.000000    15.000000
# 75%           797.500000       47883.000000  2013.0     5.000000    25.000000
# max          1365.000000       81947.000000  2013.0     6.000000    31.000000
#
#              hours       minute   weeknumber       rating  stress_label
# count  2455.000000  2455.000000  2455.000000  2455.000000   2455.000000
# mean     14.274134    24.409369    15.600815     2.182077      0.291650
# std       6.510618    18.665454     2.711081     1.294401      0.454614
# min       0.000000     0.000000    12.000000     1.000000      0.000000
# 25%      11.000000     7.000000    13.000000     1.000000      0.000000
# 50%      15.000000    22.000000    15.000000     2.000000      0.000000
# 75%      19.000000    40.000000    18.000000     3.000000      1.000000
# max      23.000000    59.000000    22.000000     5.000000      1.000000
#
# [8 rows x 34 columns]

# %% [markdown]
# ## Dropping columns

# %%
df = df.sample(frac= 1,random_state=2022)
df
# Out:
#      user_id            date_time  activity_inf_stationary_count  \
# 2391     u33  2013-04-04 23:42:00                           7679
# 1383     u27  2013-04-15 21:00:00                           7689
# 962      u41  2013-04-08 22:47:00                           1589
# 1063     u39  2013-04-16 23:34:00                           8079
# 2292     u49  2013-05-16 19:11:00                          14590
# ...      ...                  ...                            ...
# 1713     u08  2013-03-26 19:04:00                              0
# 624      u36  2013-04-17 01:55:00                           7565
# 173      u51  2013-04-30 17:06:00                           7966
# 1244     u10  2013-04-08 21:04:00                           7680
# 893      u58  2013-04-02 18:04:00                           7885
#
#       activity_inf_walking_count  activity_inf_running_count  \
# 2391                         359                          71
# 1383                         230                           1
# 962                            1                           0
# 1063                          83                          13
# 2292                         660                          92
# ...                          ...                         ...
# 1713                           0                           0
# 624                          330                         128
# 173                          179                         118
# 1244                         356                          46
# 893                          231                          40
#
#       activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 2391                          61                             47
# 1383                         193                             12
# 962                            2                              3
# 1063                         104                              6
# 2292                          86                             23
# ...                          ...                            ...
# 1713                           0                             13
# 624                          168                             15
# 173                           13                              6
# 1244                          60                              9
# 893                           63                             15
#
#       app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 2391                               43                               47
# 1383                               11                               36
# 962                                 3                                3
# 1063                                6                                9
# 2292                               20                               25
# ...                               ...                              ...
# 1713                               11                               20
# 624                                13                               17
# 173                                 6                                9
# 1244                                9                               11
# 893                                14                               22
#
#       app_usage_baseActivity_numActivities  ...  year  month  day  hours  \
# 2391                                  8703  ...  2013      4    4     23
# 1383                                   779  ...  2013      4   15     21
# 962                                     70  ...  2013      4    8     22
# 1063                                   312  ...  2013      4   16     23
# 2292                                  1394  ...  2013      5   16     19
# ...                                    ...  ...   ...    ...  ...    ...
# 1713                                   465  ...  2013      3   26     19
# 624                                    880  ...  2013      4   17      1
# 173                                    348  ...  2013      4   30     17
# 1244                                   842  ...  2013      4    8     21
# 893                                    814  ...  2013      4    2     18
#
#       minute  weekday  weeknumber  label_source  rating  stress_label
# 2391      42      Thu          13    stress_ema       1             0
# 1383       0      Mon          15    stress_ema       1             0
# 962       47      Mon          14    stress_ema       1             0
# 1063      34      Tue          15    stress_ema       1             0
# 2292      11      Thu          19    stress_ema       5             0
# ...      ...      ...         ...           ...     ...           ...
# 1713       4      Tue          12    stress_ema       2             1
# 624       55      Wed          15    stress_ema       2             1
# 173        6      Tue          17    stress_ema       3             1
# 1244       4      Mon          14    stress_ema       5             0
# 893        4      Tue          13    stress_ema       1             0
#
# [2455 rows x 38 columns]

# %%
df = df.drop(['user_id','date_time','year','label_source','rating'],axis=1)

df['stress_label'].value_counts()
# Out:
# 0    1739
# 1     716
# Name: stress_label, dtype: int64

# %%
df['weekday'].value_counts()
# Out:
# Wed    392
# Tue    385
# Thu    375
# Fri    373
# Mon    362
# Sun    330
# Sat    238
# Name: weekday, dtype: int64

# %%
weekday_map = {"Sat":0,"Sun":1,"Mon":2,"Tue":3,"Wed":4,"Thu":5,"Fri":6}

df['weekday'] = df['weekday'].map(weekday_map)

df['weekday'].value_counts()
# Out:
# 4    392
# 3    385
# 5    375
# 6    373
# 2    362
# 1    330
# 0    238
# Name: weekday, dtype: int64

# %%
df = df.reset_index(drop=True)
df
# Out:
#       activity_inf_stationary_count  activity_inf_walking_count  \
# 0                              7679                         359
# 1                              7689                         230
# 2                              1589                           1
# 3                              8079                          83
# 4                             14590                         660
# ...                             ...                         ...
# 2450                              0                           0
# 2451                           7565                         330
# 2452                           7966                         179
# 2453                           7680                         356
# 2454                           7885                         231
#
#       activity_inf_running_count  activity_inf_unknown_count  \
# 0                             71                          61
# 1                              1                         193
# 2                              0                           2
# 3                             13                         104
# 4                             92                          86
# ...                          ...                         ...
# 2450                           0                           0
# 2451                         128                         168
# 2452                         118                          13
# 2453                          46                          60
# 2454                          40                          63
#
#       app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# 0                                47                               43
# 1                                12                               11
# 2                                 3                                3
# 3                                 6                                6
# 4                                23                               20
# ...                             ...                              ...
# 2450                             13                               11
# 2451                             15                               13
# 2452                              6                                6
# 2453                              9                                9
# 2454                             15                               14
#
#       app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# 0                                  47                                  8703
# 1                                  36                                   779
# 2                                   3                                    70
# 3                                   9                                   312
# 4                                  25                                  1394
# ...                               ...                                   ...
# 2450                               20                                   465
# 2451                               17                                   880
# 2452                                9                                   348
# 2453                               11                                   842
# 2454                               22                                   814
#
#       app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# 0                                  1863                            53  ...
# 1                                   741                            16  ...
# 2                                    66                             5  ...
# 3                                   312                             6  ...
# 4                                  1240                            23  ...
# ...                                 ...                           ...  ...
# 2450                                423                            14  ...
# 2451                                806                            18  ...
# 2452                                348                             6  ...
# 2453                                801                            11  ...
# 2454                                784                            16  ...
#
#       phonelock_hours  phonelock_minutes  phonelock_seconds  month  day  \
# 0                   2                136               8179      4    4
# 1                   6                392              23578      4   15
# 2                   0                  0                  0      4    8
# 3                   1                 86               5173      4   16
# 4                  12                760              45652      5   16
# ...               ...                ...                ...    ...  ...
# 2450                0                  0                  0      3   26
# 2451                6                394              23699      4   17
# 2452               16               1017              61047      4   30
# 2453               16                960              57611      4    8
# 2454               12                768              46090      4    2
#
#       hours  minute  weekday  weeknumber  stress_label
# 0        23      42        5          13             0
# 1        21       0        2          15             0
# 2        22      47        2          14             0
# 3        23      34        3          15             0
# 4        19      11        5          19             0
# ...     ...     ...      ...         ...           ...
# 2450     19       4        3          12             1
# 2451      1      55        4          15             1
# 2452     17       6        3          17             1
# 2453     21       4        2          14             0
# 2454     18       4        3          13             0
#
# [2455 rows x 33 columns]

# %% [markdown]
# ## Train val split

# %%
df_train,df_val,df_test = df[:(len(df)*3)//5],df[(len(df)*3)//5:(len(df)*4)//5],df[(len(df)*4)//5:]

len(df_train),len(df_val),len(df_test)
# Out:
# (1473, 491, 491)

# %%
df_train[df_train.columns[-1]]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1468    0
# 1469    0
# 1470    0
# 1471    0
# 1472    0
# Name: stress_label, Length: 1473, dtype: int64

# %% [markdown]
# ## LGBM

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 500)
  min_child_samples_hp = trial.suggest_int('min_child_samples', 10, 100)
  num_leaves_hp = trial.suggest_int('num_leaves', 2, 256)
  learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
  
  model = LGBMClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_child_samples = min_child_samples_hp,
                         num_leaves = num_leaves_hp,
                         learning_rate = learning_rate_hp,
                         random_state = 0,is_unbalance=True)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 11:41:14,009] A new study created in memory with name: no-name-e0bd45af-cc16-478f-aeac-c1383a8015fc
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:14,936] Trial 0 finished with value: 0.7596761927633686 and parameters: {'n_estimators': 868, 'max_depth': 125, 'min_child_samples': 34, 'num_leaves': 188, 'learning_rate': 0.011622792692816726}. Best is trial 0 with value: 0.7596761927633686.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:14,972] Trial 1 finished with value: 0.7044208293307718 and parameters: {'n_estimators': 70, 'max_depth': 424, 'min_child_samples': 38, 'num_leaves': 14, 'learning_rate': 0.005298877649802884}. Best is trial 0 with value: 0.7596761927633686.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:15,023] Trial 2 finished with value: 0.6923631123919308 and parameters: {'n_estimators': 158, 'max_depth': 18, 'min_child_samples': 98, 'num_leaves': 18, 'learning_rate': 0.001619558635450259}. Best is trial 0 with value: 0.7596761927633686.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:15,252] Trial 3 finished with value: 0.7595160902977905 and parameters: {'n_estimators': 100, 'max_depth': 443, 'min_child_samples': 11, 'num_leaves': 156, 'learning_rate': 0.2399022175152362}. Best is trial 0 with value: 0.7596761927633686.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:15,324] Trial 4 finished with value: 0.7552233429394812 and parameters: {'n_estimators': 99, 'max_depth': 374, 'min_child_samples': 93, 'num_leaves': 78, 'learning_rate': 0.3006558987040488}. Best is trial 0 with value: 0.7596761927633686.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:15,402] Trial 5 finished with value: 0.6831672270252962 and parameters: {'n_estimators': 190, 'max_depth': 66, 'min_child_samples': 77, 'num_leaves': 216, 'learning_rate': 0.0005706010328049833}. Best is trial 0 with value: 0.7596761927633686.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41

# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:47,440] Trial 45 finished with value: 0.7590357829010568 and parameters: {'n_estimators': 707, 'max_depth': 144, 'min_child_samples': 27, 'num_leaves': 209, 'learning_rate': 0.10273668763763488}. Best is trial 37 with value: 0.767601264809478.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:47,708] Trial 46 finished with value: 0.7551833173230869 and parameters: {'n_estimators': 207, 'max_depth': 18, 'min_child_samples': 34, 'num_leaves': 141, 'learning_rate': 0.013462452909172102}. Best is trial 37 with value: 0.767601264809478.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:48,610] Trial 47 finished with value: 0.7471882004482868 and parameters: {'n_estimators': 455, 'max_depth': 244, 'min_child_samples': 85, 'num_leaves': 173, 'learning_rate': 0.058365942895305}. Best is trial 37 with value: 0.767601264809478.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:49,356] Trial 48 finished with value: 0.7642791386487351 and parameters: {'n_estimators': 937, 'max_depth': 95, 'min_child_samples': 13, 'num_leaves': 123, 'learning_rate': 0.22742140324145657}. Best is trial 37 with value: 0.767601264809478.
# /tmp/ipykernel_2461255/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 11:41:49,886] Trial 49 finished with value: 0.7573947326288826 and parameters: {'n_estimators': 973, 'max_depth': 83, 'min_child_samples': 10, 'num_leaves': 73, 'learning_rate': 0.25777548030108205}. Best is trial 37 with value: 0.767601264809478.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))


# {'n_estimators': 139, 'max_depth': 99, 'min_child_samples': 20, 'num_leaves': 208, 'learning_rate': 0.24949209471162204}
# Value: 0.767601264809478
# Out:
# Best trial: {'n_estimators': 139, 'max_depth': 99, 'min_child_samples': 20, 'num_leaves': 208, 'learning_rate': 0.24949209471162204}
#   Value: 0.767601264809478

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LGBMClassifier(**{'n_estimators': 139, 'max_depth': 99, 'min_child_samples': 20, 'num_leaves': 208, 'learning_rate': 0.24949209471162204}, random_state = 0,is_unbalance=True )
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.7145443196004994

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve LGBM (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       356
#            1       0.54      0.44      0.48       135
#
#     accuracy                           0.74       491
#    macro avg       0.67      0.65      0.66       491
# weighted avg       0.73      0.74      0.73       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#     Value                               Feature
# 0     538                                minute
# 1     481               audio_inf_silence_count
# 2     452            activity_inf_unknown_count
# 3     436                 audio_inf_noise_count
# 4     436            activity_inf_walking_count
# 5     435                                   day
# 6     435            activity_inf_running_count
# 7     429         activity_inf_stationary_count
# 8     405                 audio_inf_voice_count
# 9     392                  conversation_minutes
# 10    360     app_usage_baseActivity_numRunning
# 11    350  app_usage_baseActivity_numActivities
# 12    346                                 hours
# 13    308                          dark_minutes
# 14    294       app_usage_baseActivity_id_count
# 15    288                   phonecharge_minutes
# 16    287                     phonelock_minutes
# 17    204                            weeknumber
# 18    186                               weekday
# 19    182          app_usage_topActivity_mClass
# 20    156         app_usage_baseActivity_mClass
# 21     96       app_usage_baseActivity_mPackage
# 22     95                       phonelock_hours
# 23     69                     phonelock_seconds
# 24     65                   phonecharge_seconds
# 25     64                     phonecharge_hours
# 26     64                            dark_hours
# 27     50        app_usage_topActivity_mPackage
# 28     48                          dark_seconds
# 29     45                                 month
# 30     41                    conversation_hours
# 31      0               audio_inf_unknown_count

# %% [markdown]
# ## Log reg

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 32), (1473,), (491, 32), (491,), (491, 32), (491,))

# %%
sc = StandardScaler()
sc = sc.fit(df_train_x)

df_train_x_sc = sc.transform(df_train_x)
df_val_x_sc = sc.transform(df_val_x)
df_test_x_sc = sc.transform(df_test_x)

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.0001, 100)
  
  
  model = LogisticRegression(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 13:10:56,323] A new study created in memory with name: no-name-d590ce73-9bc3-495d-9875-d84666034735
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 13:10:57,095] Trial 0 finished with value: 0.6773535062439962 and parameters: {'C': 50.2432877160062}. Best is trial 0 with value: 0.6773535062439962.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 13:10:57,325] Trial 1 finished with value: 0.676853186039065 and parameters: {'C': 85.87154941485352}. Best is trial 0 with value: 0.6773535062439962.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 13:10:57,531] Trial 2 finished with value: 0.6772134165866155 and parameters: {'C': 80.07355064822833}. Best is trial 0 with value: 0.6773535062439962.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 13:10:57,746] Trial 3 finished with value: 0.6778538264489273 and parameters: {'C': 38.03896814267239}. Best is trial 3 with value: 0.6778538264489273.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 13:10:57,958] Trial 4 finished with value: 0.674811879602946 and parameters: {'C': 1.3242520782515237}. Best is trial 3 with value: 0.6778538264489273.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 13:10:58,237] Trial 5 finished with value: 0.6764529298751201 and parameters: {'C': 22.93643474515376}. Best is trial 3 with value: 0.6778538264489273.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 13:10:58,466] Trial 6 finished with value: 0.6774135446685878 and parameters: {'C': 20.3730443188129}. Best is trial 3 with value: 0.6778538264489273.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25
# [I 2022-11-25 13:11:00,578] Trial 45 finished with value: 0.6782540826128722 and parameters: {'C': 33.25590100761232}. Best is trial 45 with value: 0.6782540826128722.
# [I 2022-11-25 13:11:00,611] Trial 46 finished with value: 0.6771733909702209 and parameters: {'C': 52.20472893672761}. Best is trial 45 with value: 0.6782540826128722.
# [I 2022-11-25 13:11:00,642] Trial 47 finished with value: 0.6774935959013769 and parameters: {'C': 47.80266443114582}. Best is trial 45 with value: 0.6782540826128722.
# [I 2022-11-25 13:11:00,673] Trial 48 finished with value: 0.6772134165866154 and parameters: {'C': 24.957459841515526}. Best is trial 45 with value: 0.6782540826128722.
# [I 2022-11-25 13:11:00,704] Trial 49 finished with value: 0.677993916106308 and parameters: {'C': 34.97069586227304}. Best is trial 45 with value: 0.6782540826128722.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'C': 33.25590100761232}
#   Value: 0.6782540826128722
# Out:
# Best trial: {'C': 33.25590100761232}
#   Value: 0.6782540826128722

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LogisticRegression(**{'C': 33.25590100761232}, random_state = 0,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.6211610486891387

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Logistic Regression (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.56      0.65       356
#            1       0.34      0.61      0.44       135
#
#     accuracy                           0.57       491
#    macro avg       0.57      0.58      0.55       491
# weighted avg       0.67      0.57      0.60       491

# %% [markdown]
# ## SVM

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.001, 100)
  
  
  model = SVC(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",probability = True)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 12:44:45,528] A new study created in memory with name: no-name-1e0cd112-8245-459a-9b2a-f0ea92cfecbd
# [I 2022-11-25 12:44:46,087] Trial 0 finished with value: 0.6878802433557477 and parameters: {'C': 79.08191815753986}. Best is trial 0 with value: 0.6878802433557477.
# [I 2022-11-25 12:44:46,544] Trial 1 finished with value: 0.6929434838296511 and parameters: {'C': 52.987671342895254}. Best is trial 1 with value: 0.6929434838296511.
# [I 2022-11-25 12:44:46,972] Trial 2 finished with value: 0.6954450848543067 and parameters: {'C': 44.27010734398752}. Best is trial 2 with value: 0.6954450848543067.
# [I 2022-11-25 12:44:59,795] Trial 41 finished with value: 0.7092539225104066 and parameters: {'C': 6.896523150286028}. Best is trial 24 with value: 0.709644172270253.
# [I 2022-11-25 12:45:00,106] Trial 42 finished with value: 0.7072526416906821 and parameters: {'C': 18.610645829640262}. Best is trial 24 with value: 0.709644172270253.
# [I 2022-11-25 12:45:00,397] Trial 43 finished with value: 0.709033781620237 and parameters: {'C': 13.623568989506973}. Best is trial 24 with value: 0.709644172270253.
# [I 2022-11-25 12:45:00,609] Trial 44 finished with value: 0.6787343900096061 and parameters: {'C': 0.7895773959252033}. Best is trial 24 with value: 0.709644172270253.
# [I 2022-11-25 12:45:00,858] Trial 45 finished with value: 0.7096841978866475 and parameters: {'C': 7.599406263327467}. Best is trial 45 with value: 0.7096841978866475.
# [I 2022-11-25 12:45:01,225] Trial 46 finished with value: 0.6995777297470381 and parameters: {'C': 32.28276440218529}. Best is trial 45 with value: 0.7096841978866475.
# [I 2022-11-25 12:45:01,559] Trial 47 finished with value: 0.7016090297790587 and parameters: {'C': 24.10336044718059}. Best is trial 45 with value: 0.7096841978866475.
# [I 2022-11-25 12:45:02,082] Trial 48 finished with value: 0.6873799231508166 and parameters: {'C': 88.18668342588205}. Best is trial 45 with value: 0.7096841978866475.
# [I 2022-11-25 12:45:02,309] Trial 49 finished with value: 0.7000280179314761 and parameters: {'C': 3.8279921317694066}. Best is trial 45 with value: 0.7096841978866475.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# {'C': 7.599406263327467}
#   Value: 0.7096841978866475
# Out:
# Best trial: {'C': 7.599406263327467}
#   Value: 0.7096841978866475

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = SVC(**{'C': 7.599406263327467}, random_state = 0,class_weight="balanced",probability = True)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.6512484394506867

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Support Vector Machine (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.64      0.71       356
#            1       0.37      0.56      0.45       135
#
#     accuracy                           0.62       491
#    macro avg       0.58      0.60      0.58       491
# weighted avg       0.68      0.62      0.64       491

# %% [markdown]
# ## Random forest

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 32), (1473,), (491, 32), (491,), (491, 32), (491,))

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 100)
  min_child_samples_hp = trial.suggest_int('min_samples_split', 10, 100)
  num_leaves_hp = trial.suggest_int('min_samples_leaf', 2, 256)
  
  
  model = RandomForestClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_samples_split = min_child_samples_hp,
                         min_samples_leaf = num_leaves_hp,
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 12:25:48,615] A new study created in memory with name: no-name-4afc795f-d287-45ff-a67a-148dc5642c2a
# [I 2022-11-25 12:25:51,664] Trial 0 finished with value: 0.6573406980467499 and parameters: {'n_estimators': 866, 'max_depth': 97, 'min_samples_split': 67, 'min_samples_leaf': 198}. Best is trial 0 with value: 0.6573406980467499.
# [I 2022-11-25 12:25:52,484] Trial 1 finished with value: 0.6666266410502721 and parameters: {'n_estimators': 372, 'max_depth': 73, 'min_samples_split': 25, 'min_samples_leaf': 125}. Best is trial 1 with value: 0.6666266410502721.
# [I 2022-11-25 12:25:55,084] Trial 2 finished with value: 0.6725304194684597 and parameters: {'n_estimators': 613, 'max_depth': 15, 'min_samples_split': 85, 'min_samples_leaf': 105}. Best is trial 2 with value: 0.6725304194684597.
# [I 2022-11-25 12:25:55,293] Trial 3 finished with value: 0.6400696445725265 and parameters: {'n_estimators': 69, 'max_depth': 46, 'min_samples_split': 21, 'min_samples_leaf': 230}. Best is trial 2 with value: 0.6725304194684597.
# [I 2022-11-25 12:25:55,879] Trial 4 finished with value: 0.6875100064040987 and parameters: {'n_estimators': 192, 'max_depth': 30, 'min_samples_split': 12, 'min_samples_leaf': 75}. Best is trial 4 with value: 0.6875100064040987.
# [I 2022-11-25 12:25:58,383] Trial 5 finished with value: 0.7168087576048672 and parameters: {'n_estimators': 795, 'max_depth': 19, 'min_samples_split': 69, 'min_samples_leaf': 5}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:00,307] Trial 6 finished with value: 0.7036203170028819 and parameters: {'n_estimators': 756, 'max_depth': 26, 'min_samples_split': 54, 'min_samples_leaf': 28}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:02,154] Trial 7 finished with value: 0.6591418507845022 and parameters: {'n_estimators': 555, 'max_depth': 43, 'min_samples_split': 63, 'min_samples_leaf': 177}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:02,673] Trial 8 finished with value: 0.6632444764649376 and parameters: {'n_estimators': 147, 'max_depth': 82, 'min_samples_split': 94, 'min_samples_leaf': 254}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:05,527] Trial 9 finished with value: 0.6594420429074608 and parameters: {'n_estimators': 924, 'max_depth': 38, 'min_samples_split': 45, 'min_samples_leaf': 218}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:07,250] Trial 10 finished with value: 0.70908381364073 and parameters: {'n_estimators': 730, 'max_depth': 60, 'min_samples_split': 76, 'min_samples_leaf': 11}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:08,673] Trial 11 finished with value: 0.7154678994556517 and parameters: {'n_estimators': 720, 'max_depth': 65, 'min_samples_split': 78, 'min_samples_leaf': 6}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:11,617] Trial 12 finished with value: 0.691032260646814 and parameters: {'n_estimators': 978, 'max_depth': 63, 'min_samples_split': 97, 'min_samples_leaf': 54}. Best is trial 5 with value: 0.7168087576048672.
# [I 2022-11-25 12:26:13,386] Trial 13 finished with value: 0.7234430035222542 and parameters: {'n_estimators': 724, 'max_depth': 12, 'min_samples_split': 42, 'min_samples_leaf': 3}. Best is trial 13 with value: 0.7234430035222542.
# [I 2022-11-25 12:26:14,635] Trial 14 finished with value: 0.6921829971181557 and parameters: {'n_estimators': 411, 'max_depth': 10, 'min_samples_split': 35, 'min_samples_leaf': 57}. Best is trial 13 with value: 0.7234430035222542.
# [I 2022-11-25 12:26:17,026] Trial 15 finished with value: 0.6629743035542748 and parameters: {'n_estimators': 861, 'max_depth': 20, 'min_samples_split': 48, 'min_samples_leaf': 156}. Best is trial 13 with value: 0.7234430035222542.
# [I 2022-11-25 12:26:19,222] Trial 16 finished with value: 0.684898334934358 and parameters: {'n_estimators': 650, 'max_depth': 32, 'min_samples_split': 37, 'min_samples_leaf': 80}. Best is trial 13 with value: 0.7234430035222542.
# [I 2022-11-25 12:26:20,455] Trial 17 finished with value: 0.6982768972142172 and parameters: {'n_estimators': 463, 'max_depth': 21, 'min_samples_split': 63, 'min_samples_leaf': 39}. Best is trial 13 with value: 0.7234430035222542.
# [I 2022-11-25 12:26:23,186] Trial 18 finished with value: 0.7241334454050592 and parameters: {'n_estimators': 805, 'max_depth': 10, 'min_samples_split': 38, 'min_samples_leaf': 5}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:23,945] Trial 19 finished with value: 0.680275376240794 and parameters: {'n_estimators': 289, 'max_depth': 49, 'min_samples_split': 34, 'min_samples_leaf': 96}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:25,485] Trial 20 finished with value: 0.6971962055715658 and parameters: {'n_estimators': 618, 'max_depth': 10, 'min_samples_split': 24, 'min_samples_leaf': 44}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:27,397] Trial 21 finished with value: 0.7228726384886326 and parameters: {'n_estimators': 788, 'max_depth': 22, 'min_samples_split': 43, 'min_samples_leaf': 10}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:29,138] Trial 22 finished with value: 0.7143772014089017 and parameters: {'n_estimators': 875, 'max_depth': 33, 'min_samples_split': 45, 'min_samples_leaf': 19}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:31,489] Trial 23 finished with value: 0.7023094780659622 and parameters: {'n_estimators': 798, 'max_depth': 25, 'min_samples_split': 55, 'min_samples_leaf': 29}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:33,414] Trial 24 finished with value: 0.6882204610951008 and parameters: {'n_estimators': 692, 'max_depth': 10, 'min_samples_split': 38, 'min_samples_leaf': 68}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:36,269] Trial 25 finished with value: 0.7019992795389048 and parameters: {'n_estimators': 988, 'max_depth': 18, 'min_samples_split': 53, 'min_samples_leaf': 31}. Best is trial 18 with value: 0.7241334454050592.
# [I 2022-11-25 12:26:37,465] Trial 26 finished with value: 0.7285762888248479 and parameters: {'n_estimators': 585, 'max_depth': 35, 'min_samples_split': 29, 'min_samples_leaf': 3}. Best is trial 26 with value: 0.7285762888248479.
# [I 2022-11-25 12:26:38,866] Trial 27 finished with value: 0.6629442843419789 and parameters: {'n_estimators': 525, 'max_depth': 40, 'min_samples_split': 29, 'min_samples_leaf': 138}. Best is trial 26 with value: 0.7285762888248479.
# [I 2022-11-25 12:26:40,558] Trial 28 finished with value: 0.6931436119116235 and parameters: {'n_estimators': 556, 'max_depth': 55, 'min_samples_split': 15, 'min_samples_leaf': 50}. Best is trial 26 with value: 0.7285762888248479.
# [I 2022-11-25 12:26:42,304] Trial 29 finished with value: 0.6827569644572528 and parameters: {'n_estimators': 662, 'max_depth': 96, 'min_samples_split': 31, 'min_samples_leaf': 89}. Best is trial 26 with value: 0.7285762888248479.
# [I 2022-11-25 12:26:44,331] Trial 30 finished with value: 0.7333493435798911 and parameters: {'n_estimators': 840, 'max_depth': 36, 'min_samples_split': 28, 'min_samples_leaf': 2}. Best is trial 30 with value: 0.7333493435798911.
# [I 2022-11-25 12:26:46,482] Trial 31 finished with value: 0.7398434998398975 and parameters: {'n_estimators': 836, 'max_depth': 34, 'min_samples_split': 17, 'min_samples_leaf': 5}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:26:48,843] Trial 32 finished with value: 0.7090537944284342 and parameters: {'n_estimators': 855, 'max_depth': 39, 'min_samples_split': 16, 'min_samples_leaf': 23}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:26:51,401] Trial 33 finished with value: 0.699447646493756 and parameters: {'n_estimators': 917, 'max_depth': 49, 'min_samples_split': 20, 'min_samples_leaf': 37}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:26:53,335] Trial 34 finished with value: 0.6672270252961896 and parameters: {'n_estimators': 823, 'max_depth': 32, 'min_samples_split': 10, 'min_samples_leaf': 117}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:26:55,705] Trial 35 finished with value: 0.6899415626000642 and parameters: {'n_estimators': 909, 'max_depth': 55, 'min_samples_split': 28, 'min_samples_leaf': 64}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:26:56,882] Trial 36 finished with value: 0.7082732949087417 and parameters: {'n_estimators': 462, 'max_depth': 35, 'min_samples_split': 21, 'min_samples_leaf': 23}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:26:58,252] Trial 37 finished with value: 0.7354106628242076 and parameters: {'n_estimators': 586, 'max_depth': 28, 'min_samples_split': 25, 'min_samples_leaf': 3}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:26:58,999] Trial 38 finished with value: 0.7127161383285303 and parameters: {'n_estimators': 310, 'max_depth': 28, 'min_samples_split': 17, 'min_samples_leaf': 20}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:00,870] Trial 39 finished with value: 0.6975964617355108 and parameters: {'n_estimators': 561, 'max_depth': 42, 'min_samples_split': 25, 'min_samples_leaf': 42}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:02,686] Trial 40 finished with value: 0.6602825808517452 and parameters: {'n_estimators': 599, 'max_depth': 46, 'min_samples_split': 24, 'min_samples_leaf': 177}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:04,257] Trial 41 finished with value: 0.7295168908101185 and parameters: {'n_estimators': 774, 'max_depth': 16, 'min_samples_split': 29, 'min_samples_leaf': 5}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:06,057] Trial 42 finished with value: 0.7284061799551714 and parameters: {'n_estimators': 471, 'max_depth': 26, 'min_samples_split': 31, 'min_samples_leaf': 2}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:08,306] Trial 43 finished with value: 0.7228326128722382 and parameters: {'n_estimators': 684, 'max_depth': 36, 'min_samples_split': 12, 'min_samples_leaf': 15}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:10,262] Trial 44 finished with value: 0.6993475824527696 and parameters: {'n_estimators': 743, 'max_depth': 17, 'min_samples_split': 19, 'min_samples_leaf': 34}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:11,565] Trial 45 finished with value: 0.7212916266410503 and parameters: {'n_estimators': 605, 'max_depth': 29, 'min_samples_split': 28, 'min_samples_leaf': 16}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:14,151] Trial 46 finished with value: 0.7367615273775217 and parameters: {'n_estimators': 955, 'max_depth': 24, 'min_samples_split': 24, 'min_samples_leaf': 2}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:16,469] Trial 47 finished with value: 0.692383125200128 and parameters: {'n_estimators': 941, 'max_depth': 15, 'min_samples_split': 15, 'min_samples_leaf': 53}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:18,892] Trial 48 finished with value: 0.7041406500160103 and parameters: {'n_estimators': 882, 'max_depth': 23, 'min_samples_split': 23, 'min_samples_leaf': 28}. Best is trial 31 with value: 0.7398434998398975.
# [I 2022-11-25 12:27:22,447] Trial 49 finished with value: 0.6592819404418828 and parameters: {'n_estimators': 954, 'max_depth': 15, 'min_samples_split': 34, 'min_samples_leaf': 225}. Best is trial 31 with value: 0.7398434998398975.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# {'n_estimators': 637, 'max_depth': 72, 'min_samples_split': 24, 'min_samples_leaf': 9}
#   Value: 0.7340597982708934
# Out:
# Best trial: {'n_estimators': 836, 'max_depth': 34, 'min_samples_split': 17, 'min_samples_leaf': 5}
#   Value: 0.7398434998398975

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = RandomForestClassifier(**{'n_estimators': 637, 'max_depth': 72, 'min_samples_split': 24, 'min_samples_leaf': 9},random_state = 0 ,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.6991468997086975

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Random Forest (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.79       356
#            1       0.45      0.50      0.47       135
#
#     accuracy                           0.70       491
#    macro avg       0.63      0.63      0.63       491
# weighted avg       0.71      0.70      0.70       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#        Value                               Feature
# 0   0.067434                            weeknumber
# 1   0.066956            activity_inf_unknown_count
# 2   0.062972                                   day
# 3   0.057664         activity_inf_stationary_count
# 4   0.048733               audio_inf_silence_count
# 5   0.047221            activity_inf_walking_count
# 6   0.045339     app_usage_baseActivity_numRunning
# 7   0.037387            activity_inf_running_count
# 8   0.034396  app_usage_baseActivity_numActivities
# 9   0.034385                  conversation_minutes
# 10  0.034188                 audio_inf_voice_count
# 11  0.033824                 audio_inf_noise_count
# 12  0.033538       app_usage_baseActivity_id_count
# 13  0.031205                                minute
# 14  0.028936                          dark_seconds
# 15  0.027160                     phonelock_seconds
# 16  0.026856                     phonelock_minutes
# 17  0.026303          app_usage_topActivity_mClass
# 18  0.025965                                 month
# 19  0.025794                          dark_minutes
# 20  0.023801         app_usage_baseActivity_mClass
# 21  0.023630                   phonecharge_minutes
# 22  0.022968                   phonecharge_seconds
# 23  0.021236       app_usage_baseActivity_mPackage
# 24  0.020474        app_usage_topActivity_mPackage
# 25  0.018671                                 hours
# 26  0.016014                       phonelock_hours
# 27  0.015778                               weekday
# 28  0.015093                            dark_hours
# 29  0.013379                    conversation_hours
# 30  0.012701                     phonecharge_hours
# 31  0.000000               audio_inf_unknown_count

# %% [markdown]
# ## End
