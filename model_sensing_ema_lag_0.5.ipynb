# %%
### importing libraries

from datetime import datetime,timedelta
from collections import defaultdict
from tqdm import tqdm

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import json
import os
import gc

from lightgbm import LGBMClassifier
import optuna

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,roc_curve,confusion_matrix,accuracy_score,auc,classification_report

# %% [markdown]
# ## load dataset

# %%
df1 = pd.read_csv('./data/sensing_data_0.5.csv')
df1.head()
# Out:
#   user_id            date_time  activity_inf_stationary_count  \
# 0     u17  2013-03-28 15:08:00                           3664
# 1     u17  2013-03-30 16:06:00                           4045
# 2     u17  2013-04-11 16:53:00                           3640
# 3     u17  2013-04-14 15:33:00                           4014
# 4     u17  2013-04-15 14:07:00                           3653
#
#    activity_inf_walking_count  activity_inf_running_count  \
# 0                         315                          62
# 1                          18                           0
# 2                         362                          15
# 3                         112                           0
# 4                         269                          75
#
#    activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 0                          65                              5
# 1                          16                              9
# 2                          78                              5
# 3                          22                              6
# 4                         129                             11
#
#    app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 0                                5                                9
# 1                                9                               17
# 2                                5                                6
# 3                                6                                6
# 4                               10                               12
#
#    app_usage_baseActivity_numActivities  ...  year  month  day  hours  minute  \
# 0                                   156  ...  2013      3   28     15       8
# 1                                   237  ...  2013      3   30     16       6
# 2                                   180  ...  2013      4   11     16      53
# 3                                   434  ...  2013      4   14     15      33
# 4                                   377  ...  2013      4   15     14       7
#
#    weekday  weeknumber  label_source  rating  stress_label
# 0      Thu          12    stress_ema       1             0
# 1      Sat          12    stress_ema       2             1
# 2      Thu          14    stress_ema       3             1
# 3      Sun          14    stress_ema       3             1
# 4      Mon          15    stress_ema       3             1
#
# [5 rows x 38 columns]

# %%
df1.columns,df1.columns[-10:]
# Out:
# (Index(['user_id', 'date_time', 'activity_inf_stationary_count',
#         'activity_inf_walking_count', 'activity_inf_running_count',
#         'activity_inf_unknown_count', 'app_usage_baseActivity_mClass',
#         'app_usage_baseActivity_mPackage', 'app_usage_baseActivity_id_count',
#         'app_usage_baseActivity_numActivities',
#         'app_usage_baseActivity_numRunning', 'app_usage_topActivity_mClass',
#         'app_usage_topActivity_mPackage', 'audio_inf_silence_count',
#         'audio_inf_voice_count', 'audio_inf_noise_count',
#         'audio_inf_unknown_count', 'conversation_hours', 'conversation_minutes',
#         'dark_hours', 'dark_minutes', 'dark_seconds', 'phonecharge_hours',
#         'phonecharge_minutes', 'phonecharge_seconds', 'phonelock_hours',
#         'phonelock_minutes', 'phonelock_seconds', 'year', 'month', 'day',
#         'hours', 'minute', 'weekday', 'weeknumber', 'label_source', 'rating',
#         'stress_label'],
#        dtype='object'),
#  Index(['year', 'month', 'day', 'hours', 'minute', 'weekday', 'weeknumber',
#         'label_source', 'rating', 'stress_label'],
#        dtype='object'))

# %%
df1 = df1.drop(df1.columns[-10:],axis=1)
df1.columns
# Out:
# Index(['user_id', 'date_time', 'activity_inf_stationary_count',
#        'activity_inf_walking_count', 'activity_inf_running_count',
#        'activity_inf_unknown_count', 'app_usage_baseActivity_mClass',
#        'app_usage_baseActivity_mPackage', 'app_usage_baseActivity_id_count',
#        'app_usage_baseActivity_numActivities',
#        'app_usage_baseActivity_numRunning', 'app_usage_topActivity_mClass',
#        'app_usage_topActivity_mPackage', 'audio_inf_silence_count',
#        'audio_inf_voice_count', 'audio_inf_noise_count',
#        'audio_inf_unknown_count', 'conversation_hours', 'conversation_minutes',
#        'dark_hours', 'dark_minutes', 'dark_seconds', 'phonecharge_hours',
#        'phonecharge_minutes', 'phonecharge_seconds', 'phonelock_hours',
#        'phonelock_minutes', 'phonelock_seconds'],
#       dtype='object')

# %%
df2 = pd.read_csv('./data/ema_data_0.5.csv')
df2.head()
# Out:
#   user_id            date_time  number_Social  experience_Class_neutral  \
# 0     u22  2013-03-27 00:35:00              0                         0
# 1     u22  2013-03-27 15:03:00              0                         1
# 2     u22  2013-03-27 20:06:00              0                         2
# 3     u22  2013-03-28 00:20:00              2                         1
# 4     u22  2013-03-28 03:00:00             32                         1
#
#    experience_Class_st_agree  experience_Class_agree  \
# 0                          0                       0
# 1                          0                       0
# 2                          0                       1
# 3                          0                       1
# 4                          0                       1
#
#    experience_Class_disagree  experience_Class_st_disagree  due_Class_yes  \
# 0                          0                             0              0
# 1                          0                             0              0
# 2                          0                             0              0
# 3                          0                             0              0
# 4                          0                             0              0
#
#    due_Class_no  ...  year  month  day  hours  minute  weekday  weeknumber  \
# 0             0  ...  2013      3   27      0      35      Wed          12
# 1             1  ...  2013      3   27     15       3      Wed          12
# 2             3  ...  2013      3   27     20       6      Wed          12
# 3             2  ...  2013      3   28      0      20      Thu          12
# 4             2  ...  2013      3   28      3       0      Thu          12
#
#    label_source  rating  stress_label
# 0    stress_ema       1             0
# 1    stress_ema       1             0
# 2    stress_ema       4             0
# 3    stress_ema       5             0
# 4    stress_ema       5             0
#
# [5 rows x 66 columns]

# %%
df = df1.merge(df2,on=['user_id','date_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2455 entries, 0 to 2454
# Data columns (total 92 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   user_id                               2455 non-null   object
#  1   date_time                             2455 non-null   object
#  2   activity_inf_stationary_count         2455 non-null   int64
#  3   activity_inf_walking_count            2455 non-null   int64
#  4   activity_inf_running_count            2455 non-null   int64
#  5   activity_inf_unknown_count            2455 non-null   int64
#  6   app_usage_baseActivity_mClass         2455 non-null   int64
#  7   app_usage_baseActivity_mPackage       2455 non-null   int64
#  8   app_usage_baseActivity_id_count       2455 non-null   int64
#  9   app_usage_baseActivity_numActivities  2455 non-null   int64
#  10  app_usage_baseActivity_numRunning     2455 non-null   int64
#  11  app_usage_topActivity_mClass          2455 non-null   int64
#  12  app_usage_topActivity_mPackage        2455 non-null   int64
#  13  audio_inf_silence_count               2455 non-null   int64
#  14  audio_inf_voice_count                 2455 non-null   int64
#  15  audio_inf_noise_count                 2455 non-null   int64
#  16  audio_inf_unknown_count               2455 non-null   int64
#  17  conversation_hours                    2455 non-null   int64
#  18  conversation_minutes                  2455 non-null   int64
#  19  dark_hours                            2455 non-null   int64
#  20  dark_minutes                          2455 non-null   int64
#  81  grade_C_min                           2455 non-null   int64
#  82  year                                  2455 non-null   int64
#  83  month                                 2455 non-null   int64
#  84  day                                   2455 non-null   int64
#  85  hours                                 2455 non-null   int64
#  86  minute                                2455 non-null   int64
#  87  weekday                               2455 non-null   object
#  88  weeknumber                            2455 non-null   int64
#  89  label_source                          2455 non-null   object
#  90  rating                                2455 non-null   int64
#  91  stress_label                          2455 non-null   int64
# dtypes: int64(88), object(4)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#        activity_inf_stationary_count  activity_inf_walking_count  \
# count                    2455.000000                 2455.000000
# mean                     4376.148676                  303.131976
# std                      3530.497803                  471.641989
# min                         0.000000                    0.000000
# 25%                      3398.500000                   91.000000
# 50%                      3744.000000                  186.000000
# 75%                      3971.000000                  314.000000
# max                     20949.000000                 5010.000000
#
#        activity_inf_running_count  activity_inf_unknown_count  \
# count                 2455.000000                 2455.000000
# mean                    77.894501                  189.774745
# std                    137.610712                  421.146866
# min                      0.000000                    0.000000
# 25%                      1.000000                   26.000000
# 50%                     28.000000                   62.000000
# 75%                     92.500000                  159.000000
# max                   2051.000000                 6594.000000
#
#        app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# count                    2455.000000                      2455.000000
# mean                       14.379226                        13.268024
# std                         9.087323                         8.148470
# min                         0.000000                         0.000000
# 25%                         8.000000                         8.000000
# 50%                        13.000000                        12.000000
# 75%                        19.000000                        17.000000
# max                        62.000000                        57.000000
#
#        app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# count                      2455.000000                           2455.000000
# mean                         17.239919                            594.028513
# std                          10.715056                            636.876830
# min                           0.000000                              0.000000
# 25%                          10.000000                            212.000000
# 50%                          16.000000                            436.000000
# 75%                          22.000000                            726.500000
# max                          78.000000                           4668.000000
#
#        app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# count                        2455.000000                   2455.000000  ...
# mean                          343.393483                     16.788187  ...
# std                           241.768032                     10.345968  ...
# min                             0.000000                      0.000000  ...
# 25%                           144.000000                     10.000000  ...
# 50%                           293.000000                     16.000000  ...
# 75%                           501.000000                     22.000000  ...
# max                          1981.000000                     73.000000  ...
#
#        grade_C  grade_C_min    year        month          day        hours  \
# count   2455.0       2455.0  2455.0  2455.000000  2455.000000  2455.000000
# mean       0.0          0.0  2013.0     4.224847    15.397963    14.274134
# std        0.0          0.0     0.0     0.664591     9.455342     6.510618
# min        0.0          0.0  2013.0     3.000000     1.000000     0.000000
# 25%        0.0          0.0  2013.0     4.000000     7.000000    11.000000
# 50%        0.0          0.0  2013.0     4.000000    15.000000    15.000000
# 75%        0.0          0.0  2013.0     5.000000    25.000000    19.000000
# max        0.0          0.0  2013.0     6.000000    31.000000    23.000000
#
#             minute   weeknumber       rating  stress_label
# count  2455.000000  2455.000000  2455.000000   2455.000000
# mean     24.409369    15.600815     2.182077      0.291650
# std      18.665454     2.711081     1.294401      0.454614
# min       0.000000    12.000000     1.000000      0.000000
# 25%       7.000000    13.000000     1.000000      0.000000
# 50%      22.000000    15.000000     2.000000      0.000000
# 75%      40.000000    18.000000     3.000000      1.000000
# max      59.000000    22.000000     5.000000      1.000000
#
# [8 rows x 88 columns]

# %% [markdown]
# ## Dropping columns

# %%
df = df.sample(frac= 1,random_state=2022)
df
# Out:
#      user_id            date_time  activity_inf_stationary_count  \
# 2391     u33  2013-04-04 23:42:00                           3872
# 1383     u27  2013-04-15 21:00:00                           3604
# 962      u41  2013-04-08 22:47:00                           1589
# 1063     u39  2013-04-16 23:34:00                           3995
# 2292     u49  2013-05-16 19:11:00                           6924
# ...      ...                  ...                            ...
# 1713     u08  2013-03-26 19:04:00                              0
# 624      u36  2013-04-17 01:55:00                           3693
# 173      u51  2013-04-30 17:06:00                           3944
# 1244     u10  2013-04-08 21:04:00                           3774
# 893      u58  2013-04-02 18:04:00                           3741
#
#       activity_inf_walking_count  activity_inf_running_count  \
# 2391                         191                           0
# 1383                         203                           1
# 962                            1                           0
# 1063                          62                          13
# 2292                         415                          48
# ...                          ...                         ...
# 1713                           0                           0
# 624                          247                          75
# 173                           47                         118
# 1244                         182                          46
# 893                          231                          40
#
#       activity_inf_unknown_count  app_usage_baseActivity_mClass  \
# 2391                          32                             46
# 1383                         187                             11
# 962                            2                              3
# 1063                          58                              6
# 2292                          43                             17
# ...                          ...                            ...
# 1713                           0                             13
# 624                           74                             13
# 173                           13                              6
# 1244                          30                              9
# 893                           57                             14
#
#       app_usage_baseActivity_mPackage  app_usage_baseActivity_id_count  \
# 2391                               43                               46
# 1383                               10                               31
# 962                                 3                                3
# 1063                                6                                9
# 2292                               14                               17
# ...                               ...                              ...
# 1713                               11                               20
# 624                                11                               13
# 173                                 6                                8
# 1244                                9                               10
# 893                                13                               20
#
#       app_usage_baseActivity_numActivities  ...  year  month  day  hours  \
# 2391                                  4132  ...  2013      4    4     23
# 1383                                   372  ...  2013      4   15     21
# 962                                     70  ...  2013      4    8     22
# 1063                                   168  ...  2013      4   16     23
# 2292                                   694  ...  2013      5   16     19
# ...                                    ...  ...   ...    ...  ...    ...
# 1713                                   105  ...  2013      3   26     19
# 624                                    554  ...  2013      4   17      1
# 173                                    169  ...  2013      4   30     17
# 1244                                   422  ...  2013      4    8     21
# 893                                    414  ...  2013      4    2     18
#
#       minute  weekday  weeknumber  label_source  rating  stress_label
# 2391      42      Thu          13    stress_ema       1             0
# 1383       0      Mon          15    stress_ema       1             0
# 962       47      Mon          14    stress_ema       1             0
# 1063      34      Tue          15    stress_ema       1             0
# 2292      11      Thu          19    stress_ema       5             0
# ...      ...      ...         ...           ...     ...           ...
# 1713       4      Tue          12    stress_ema       2             1
# 624       55      Wed          15    stress_ema       2             1
# 173        6      Tue          17    stress_ema       3             1
# 1244       4      Mon          14    stress_ema       5             0
# 893        4      Tue          13    stress_ema       1             0
#
# [2455 rows x 92 columns]

# %%
df = df.drop(['user_id','date_time','year','label_source','rating'],axis=1)

df['stress_label'].value_counts()
# Out:
# 0    1739
# 1     716
# Name: stress_label, dtype: int64

# %%
df['weekday'].value_counts()
# Out:
# Wed    392
# Tue    385
# Thu    375
# Fri    373
# Mon    362
# Sun    330
# Sat    238
# Name: weekday, dtype: int64

# %%
weekday_map = {"Sat":0,"Sun":1,"Mon":2,"Tue":3,"Wed":4,"Thu":5,"Fri":6}

df['weekday'] = df['weekday'].map(weekday_map)

df['weekday'].value_counts()
# Out:
# 4    392
# 3    385
# 5    375
# 6    373
# 2    362
# 1    330
# 0    238
# Name: weekday, dtype: int64

# %%
df = df.reset_index(drop=True)
df
# Out:
#       activity_inf_stationary_count  activity_inf_walking_count  \
# 0                              3872                         191
# 1                              3604                         203
# 2                              1589                           1
# 3                              3995                          62
# 4                              6924                         415
# ...                             ...                         ...
# 2450                              0                           0
# 2451                           3693                         247
# 2452                           3944                          47
# 2453                           3774                         182
# 2454                           3741                         231
#
#       activity_inf_running_count  activity_inf_unknown_count  \
# 0                              0                          32
# 1                              1                         187
# 2                              0                           2
# 3                             13                          58
# 4                             48                          43
# ...                          ...                         ...
# 2450                           0                           0
# 2451                          75                          74
# 2452                         118                          13
# 2453                          46                          30
# 2454                          40                          57
#
#       app_usage_baseActivity_mClass  app_usage_baseActivity_mPackage  \
# 0                                46                               43
# 1                                11                               10
# 2                                 3                                3
# 3                                 6                                6
# 4                                17                               14
# ...                             ...                              ...
# 2450                             13                               11
# 2451                             13                               11
# 2452                              6                                6
# 2453                              9                                9
# 2454                             14                               13
#
#       app_usage_baseActivity_id_count  app_usage_baseActivity_numActivities  \
# 0                                  46                                  4132
# 1                                  31                                   372
# 2                                   3                                    70
# 3                                   9                                   168
# 4                                  17                                   694
# ...                               ...                                   ...
# 2450                               20                                   105
# 2451                               13                                   554
# 2452                                8                                   169
# 2453                               10                                   422
# 2454                               20                                   414
#
#       app_usage_baseActivity_numRunning  app_usage_topActivity_mClass  ...  \
# 0                                   794                            50  ...
# 1                                   341                            14  ...
# 2                                    66                             5  ...
# 3                                   168                             6  ...
# 4                                   622                            17  ...
# ...                                 ...                           ...  ...
# 2450                                 99                            14  ...
# 2451                                516                            15  ...
# 2452                                169                             6  ...
# 2453                                409                            11  ...
# 2454                                384                            15  ...
#
#       grade_C_plu  grade_C  grade_C_min  month  day  hours  minute  weekday  \
# 0               0        0            0      4    4     23      42        5
# 1               0        0            0      4   15     21       0        2
# 2               0        0            0      4    8     22      47        2
# 3               0        0            0      4   16     23      34        3
# 4               0        0            0      5   16     19      11        5
# ...           ...      ...          ...    ...  ...    ...     ...      ...
# 2450            0        0            0      3   26     19       4        3
# 2451            0        0            0      4   17      1      55        4
# 2452            0        0            0      4   30     17       6        3
# 2453            0        0            0      4    8     21       4        2
# 2454            0        0            0      4    2     18       4        3
#
#       weeknumber  stress_label
# 0             13             0
# 1             15             0
# 2             14             0
# 3             15             0
# 4             19             0
# ...          ...           ...
# 2450          12             1
# 2451          15             1
# 2452          17             1
# 2453          14             0
# 2454          13             0
#
# [2455 rows x 87 columns]

# %% [markdown]
# ## Train val split

# %%
df_train,df_val,df_test = df[:(len(df)*3)//5],df[(len(df)*3)//5:(len(df)*4)//5],df[(len(df)*4)//5:]

len(df_train),len(df_val),len(df_test)
# Out:
# (1473, 491, 491)

# %%
df_train[df_train.columns[-1]]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1468    0
# 1469    0
# 1470    0
# 1471    0
# 1472    0
# Name: stress_label, Length: 1473, dtype: int64

# %% [markdown]
# ## LGBM

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 500)
  min_child_samples_hp = trial.suggest_int('min_child_samples', 10, 100)
  num_leaves_hp = trial.suggest_int('num_leaves', 2, 256)
  learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
  
  model = LGBMClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_child_samples = min_child_samples_hp,
                         num_leaves = num_leaves_hp,
                         learning_rate = learning_rate_hp,
                         random_state = 0,is_unbalance=True)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:22:28,689] A new study created in memory with name: no-name-d6439680-d110-4863-a818-bf5db1ad79f6
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:22:29,738] Trial 0 finished with value: 0.7069124239513289 and parameters: {'n_estimators': 484, 'max_depth': 57, 'min_child_samples': 50, 'num_leaves': 138, 'learning_rate': 0.003776253941572799}. Best is trial 0 with value: 0.7069124239513289.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:22:30,639] Trial 1 finished with value: 0.7055315401857188 and parameters: {'n_estimators': 903, 'max_depth': 354, 'min_child_samples': 38, 'num_leaves': 16, 'learning_rate': 0.020675308161980058}. Best is trial 0 with value: 0.7069124239513289.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:22:31,219] Trial 2 finished with value: 0.7099843900096061 and parameters: {'n_estimators': 384, 'max_depth': 263, 'min_child_samples': 43, 'num_leaves': 187, 'learning_rate': 0.002002400522443028}. Best is trial 2 with value: 0.7099843900096061.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:22:31,568] Trial 3 finished with value: 0.7055915786103106 and parameters: {'n_estimators': 323, 'max_depth': 382, 'min_child_samples': 70, 'num_leaves': 232, 'learning_rate': 0.017888417265652455}. Best is trial 2 with value: 0.7099843900096061.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:22:32,109] Trial 4 finished with value: 0.6531079891130323 and parameters: {'n_estimators': 326, 'max_depth': 463, 'min_child_samples': 35, 'num_leaves': 23, 'learning_rate': 4.00243646597496e-05}. Best is trial 2 with value: 0.7099843900096061.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:22:32,870] Trial 5 finished with value: 0.6924131444124241 and parameters: {'n_estimators': 747, 'max_depth': 22, 'min_child_samples': 70, 'num_leaves': 50, 'learning_rate': 0.21417175574773273}. Best is trial 2 with value: 0.7099843900096061.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:22

# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:02,559] Trial 32 finished with value: 0.7249439641370478 and parameters: {'n_estimators': 854, 'max_depth': 232, 'min_child_samples': 18, 'num_leaves': 34, 'learning_rate': 0.0017471490845862492}. Best is trial 32 with value: 0.7249439641370478.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:04,295] Trial 33 finished with value: 0.721962055715658 and parameters: {'n_estimators': 857, 'max_depth': 282, 'min_child_samples': 18, 'num_leaves': 37, 'learning_rate': 0.0020481928573131115}. Best is trial 32 with value: 0.7249439641370478.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:06,072] Trial 34 finished with value: 0.7223723182837016 and parameters: {'n_estimators': 861, 'max_depth': 338, 'min_child_samples': 20, 'num_leaves': 34, 'learning_rate': 0.013670249573482385}. Best is trial 32 with value: 0.7249439641370478.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:07,145] Trial 35 finished with value: 0.7105747678514249 and parameters: {'n_estimators': 710, 'max_depth': 389, 'min_child_samples': 20, 'num_leaves': 24, 'learning_rate': 0.019304410057159504}. Best is trial 32 with value: 0.7249439641370478.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:08,889] Trial 36 finished with value: 0.7250040025616394 and parameters: {'n_estimators': 831, 'max_depth': 430, 'min_child_samples': 10, 'num_leaves': 32, 'learning_rate': 0.005331094147458518}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:10,019] Trial 37 finished with value: 0.6867395132885046 and parameters: {'n_estimators': 795, 'max_depth': 417, 'min_child_samples': 10, 'num_leaves': 6, 'learning_rate': 0.004992577806885464}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:12,081] Trial 38 finished with value: 0.6992575248158821 and parameters: {'n_estimators': 697, 'max_depth': 489, 'min_child_samples': 15, 'num_leaves': 46, 'learning_rate': 0.0002799843685624329}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:13,399] Trial 39 finished with value: 0.6673671149535704 and parameters: {'n_estimators': 798, 'max_depth': 424, 'min_child_samples': 23, 'num_leaves': 23, 'learning_rate': 1.3710404978045255e-05}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:15,032] Trial 40 finished with value: 0.6623338936919629 and parameters: {'n_estimators': 929, 'max_depth': 158, 'min_child_samples': 35, 'num_leaves': 53, 'learning_rate': 0.00010862167032861773}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:16,602] Trial 41 finished with value: 0.7134966378482228 and parameters: {'n_estimators': 878, 'max_depth': 335, 'min_child_samples': 24, 'num_leaves': 34, 'learning_rate': 0.02143760006303673}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:17,604] Trial 42 finished with value: 0.7036203170028817 and parameters: {'n_estimators': 830, 'max_depth': 350, 'min_child_samples': 16, 'num_leaves': 16, 'learning_rate': 0.012406487273659174}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:17,796] Trial 43 finished with value: 0.658161223182837 and parameters: {'n_estimators': 940, 'max_depth': 397, 'min_child_samples': 47, 'num_leaves': 2, 'learning_rate': 0.001342182282594902}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:18,992] Trial 44 finished with value: 0.7129662984309959 and parameters: {'n_estimators': 754, 'max_depth': 285, 'min_child_samples': 10, 'num_leaves': 32, 'learning_rate': 0.1292833982321891}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:20,764] Trial 45 finished with value: 0.7194604546910023 and parameters: {'n_estimators': 657, 'max_depth': 249, 'min_child_samples': 23, 'num_leaves': 89, 'learning_rate': 0.030442301555522397}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:22,335] Trial 46 finished with value: 0.714127041306436 and parameters: {'n_estimators': 896, 'max_depth': 363, 'min_child_samples': 34, 'num_leaves': 47, 'learning_rate': 0.004368487410508964}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:23,458] Trial 47 finished with value: 0.6967058917707333 and parameters: {'n_estimators': 840, 'max_depth': 436, 'min_child_samples': 13, 'num_leaves': 18, 'learning_rate': 0.007974082662527842}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:26,708] Trial 48 finished with value: 0.701969260326609 and parameters: {'n_estimators': 568, 'max_depth': 297, 'min_child_samples': 16, 'num_leaves': 58, 'learning_rate': 0.00041573632647614006}. Best is trial 36 with value: 0.7250040025616394.
# /tmp/ipykernel_2483076/3744688316.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   learning_rate_hp = trial.suggest_loguniform('learning_rate',1e-5,10)
# [I 2022-11-25 15:23:27,415] Trial 49 finished with value: 0.7046609830291386 and parameters: {'n_estimators': 957, 'max_depth': 252, 'min_child_samples': 24, 'num_leaves': 27, 'learning_rate': 0.341001055528698}. Best is trial 36 with value: 0.7250040025616394.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))


# Best trial: {'n_estimators': 831, 'max_depth': 430, 'min_child_samples': 10, 'num_leaves': 32, 'learning_rate': 0.005331094147458518}
#   Value: 0.7250040025616394
# Out:
# Best trial: {'n_estimators': 831, 'max_depth': 430, 'min_child_samples': 10, 'num_leaves': 32, 'learning_rate': 0.005331094147458518}
#   Value: 0.7250040025616394

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LGBMClassifier(**{'n_estimators': 831, 'max_depth': 430, 'min_child_samples': 10, 'num_leaves': 32, 'learning_rate': 0.005331094147458518}, random_state = 0,is_unbalance=True )
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.7045359966708281

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve LGBM (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       356
#            1       0.46      0.50      0.48       135
#
#     accuracy                           0.70       491
#    macro avg       0.63      0.64      0.64       491
# weighted avg       0.71      0.70      0.70       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#     Value                       Feature
# 0    1596                           day
# 1    1538                        minute
# 2    1475    activity_inf_unknown_count
# 3    1432       audio_inf_silence_count
# 4    1338          conversation_minutes
# ..    ...                           ...
# 81      0                   grade_A_min
# 82      0  experience_Class_st_disagree
# 83      0             effort_Class 2 no
# 84      0          challenge_Class 2 no
# 85      0       audio_inf_unknown_count
#
# [86 rows x 2 columns]

# %% [markdown]
# ## Log reg

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 86), (1473,), (491, 86), (491,), (491, 86), (491,))

# %%
sc = StandardScaler()
sc = sc.fit(df_train_x)

df_train_x_sc = sc.transform(df_train_x)
df_val_x_sc = sc.transform(df_val_x)
df_test_x_sc = sc.transform(df_test_x)

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.0001, 100)
  
  
  model = LogisticRegression(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:24:20,568] A new study created in memory with name: no-name-1b06adab-5e93-4733-8e84-0e04b58ea508
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:21,310] Trial 0 finished with value: 0.6633245276977265 and parameters: {'C': 33.46449606678115}. Best is trial 0 with value: 0.6633245276977265.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:21,551] Trial 1 finished with value: 0.6632044508485431 and parameters: {'C': 35.9426171559086}. Best is trial 0 with value: 0.6633245276977265.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:21,786] Trial 2 finished with value: 0.6633845661223183 and parameters: {'C': 50.06447282584246}. Best is trial 2 with value: 0.6633845661223183.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:22,026] Trial 3 finished with value: 0.6635446685878963 and parameters: {'C': 20.659898055966323}. Best is trial 3 with value: 0.6635446685878963.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:22,263] Trial 4 finished with value: 0.6632244636567403 and parameters: {'C': 40.3846702567811}. Best is trial 3 with value: 0.6635446685878963.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:22,500] Trial 5 finished with value: 0.6641650656420108 and parameters: {'C': 80.63780697837221}. Best is trial 5 with value: 0.6641650656420108.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:22,750] Trial 6 finished with value: 0.6633245276977265 and parameters: {'C': 5.52946826235072}. Best is trial 5 with value: 0.6641650656420108.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:22,976] Trial 7 finished with value: 0.6636247198206853 and parameters: {'C': 3.448413659637527}. Best is trial 5 with value: 0.6641650656420108.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:23,223] Trial 8 finished with value: 0.6634045789305155 and parameters: {'C': 19.69949255637474}. Best is trial 5 with value: 0.6641650656420108.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:23,456] Trial 9 finished with value: 0.663764809478066 and parameters: {'C': 14.410338188994665}. Best is trial 5 with value: 0.6641650656420108.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:23,683] Trial 10 finished with value: 0.663524655779699 and parameters: {'C': 85.63544663957882}. Best is trial 5 with value: 0.6641650656420108.
# /home/sidd/anaconda3/envs/ucsd_hw/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-11-25 15:24:23,923] Trial 11 finished with value: 0.6641450528338135 and parameters: {'C': 79.89151693583345}. Best is trial 5 with value: 0.6641650656420108.
# [I 2022-11-25 15:24:23,967] Trial 12 finished with value: 0.6634446045469101 and parameters: {'C': 89.04285252435247}. Best is trial 5 with value: 0.6641650656420108.
# [I 2022-11-25 15:24
. Best is trial 5 with value: 0.6641650656420108.
# [I 2022-11-25 15:24:25,929] Trial 47 finished with value: 0.6639048991354466 and parameters: {'C': 63.00329857915814}. Best is trial 5 with value: 0.6641650656420108.
# [I 2022-11-25 15:24:25,982] Trial 48 finished with value: 0.6641050272174192 and parameters: {'C': 74.70359779566674}. Best is trial 5 with value: 0.6641650656420108.
# [I 2022-11-25 15:24:26,024] Trial 49 finished with value: 0.663604707012488 and parameters: {'C': 73.88311903281279}. Best is trial 5 with value: 0.6641650656420108.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'C': 80.63780697837221}
#   Value: 0.6641650656420108
# Out:
# Best trial: {'C': 80.63780697837221}
#   Value: 0.6641650656420108

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = LogisticRegression(**{'C': 80.63780697837221}, random_state = 0,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.6868913857677903

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Logistic Regression (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.61      0.70       356
#            1       0.40      0.67      0.50       135
#
#     accuracy                           0.63       491
#    macro avg       0.61      0.64      0.60       491
# weighted avg       0.71      0.63      0.65       491

# %% [markdown]
# ## SVM

# %%
def objective(trial):
  c_hp = trial.suggest_float('C', 0.001, 100)
  
  
  model = SVC(C = c_hp, 
                         
                         random_state = 0,class_weight="balanced",probability = True)
  
  model.fit(df_train_x_sc, df_train_y)
  
  pred_probs = model.predict_proba(df_val_x_sc)
  
  return roc_auc_score(df_val_y, pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:24:59,085] A new study created in memory with name: no-name-d11f2d67-a63f-4cde-bbc2-ead07ba9fb52
# [I 2022-11-25 15:24:59,472] Trial 0 finished with value: 0.6725604386807558 and parameters: {'C': 1.799268169638048}. Best is trial 0 with value: 0.6725604386807558.
# [I 2022-11-25 15:24:59,898] Trial 1 finished with value: 0.6261007044508485 and parameters: {'C': 24.895738118713123}. Best is trial 0 with value: 0.6725604386807558.
# [I 2022-11-25 15:25:00,386] Trial 2 finished with value: 0.612411943643932 and parameters: {'C': 54.95118666395889}. Best is trial 0 with value: 0.6725604386807558.
# [I 2022-11-25 15:25:00,846] Trial 3 finished with value: 0.6173050752481588 and parameters: {'C': 43.731642420025516}. Best is trial 0 with value: 0.6725604386807558.
# [I 2022-11-25 15:25:01,271] Trial 4 finished with value: 0.6275816522574448 and parameters: {'C': 22.849185059906137}. Best is trial 0 with value: 0.6725604386807558.
# [I 2022-11-25 15:25:17,477] Trial 43 finished with value: 0.6414405219340378 and parameters: {'C': 9.979397816655002}. Best is trial 41 with value: 0.6762327889849504.
# [I 2022-11-25 15:25:17,824] Trial 44 finished with value: 0.6668167627281459 and parameters: {'C': 2.5325103553208175}. Best is trial 41 with value: 0.6762327889849504.
# [I 2022-11-25 15:25:18,213] Trial 45 finished with value: 0.6317643291706692 and parameters: {'C': 15.128671408184317}. Best is trial 41 with value: 0.6762327889849504.
# [I 2022-11-25 15:25:18,559] Trial 46 finished with value: 0.676132724943964 and parameters: {'C': 1.0512534925932775}. Best is trial 41 with value: 0.6762327889849504.
# [I 2022-11-25 15:25:18,971] Trial 47 finished with value: 0.6289625360230549 and parameters: {'C': 21.166527810624057}. Best is trial 41 with value: 0.6762327889849504.
# [I 2022-11-25 15:25:19,342] Trial 48 finished with value: 0.6363072366314442 and parameters: {'C': 12.27813009909733}. Best is trial 41 with value: 0.6762327889849504.
# [I 2022-11-25 15:25:19,812] Trial 49 finished with value: 0.6153438200448287 and parameters: {'C': 48.58387217900058}. Best is trial 41 with value: 0.6762327889849504.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'C': 1.0471982402335112}
#   Value: 0.6762327889849504
# Out:
# Best trial: {'C': 1.0471982402335112}
#   Value: 0.6762327889849504

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = SVC(**{'C': 1.0471982402335112}, random_state = 0,class_weight="balanced",probability = True)
 
model.fit(df_train_x_sc, df_train_y)
 
roc_auc_score(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
# Out:
# 0.6579692051602164

# %%
fpr, tpr, _ = roc_curve(df_test_y, model.predict_proba(df_test_x_sc)[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Support Vector Machine (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test_y, model.predict(df_test_x_sc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73       356
#            1       0.39      0.55      0.46       135
#
#     accuracy                           0.64       491
#    macro avg       0.59      0.61      0.59       491
# weighted avg       0.69      0.64      0.66       491

# %% [markdown]
# ## Random forest

# %%
df_train_x,df_train_y = df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]]
df_val_x,df_val_y = df_val[df_val.columns[:-1]], df_val[df_val.columns[-1]]
df_test_x,df_test_y = df_test[df_test.columns[:-1]], df_test[df_test.columns[-1]]


df_train_x.shape,df_train_y.shape,df_val_x.shape,df_val_y.shape,df_test_x.shape,df_test_y.shape
# Out:
# ((1473, 86), (1473,), (491, 86), (491,), (491, 86), (491,))

# %%
def objective(trial):
  n_estimators_hp = trial.suggest_int('n_estimators', 50, 1000)
  max_depth_hp =  trial.suggest_int('max_depth', 10, 100)
  min_child_samples_hp = trial.suggest_int('min_samples_split', 10, 100)
  num_leaves_hp = trial.suggest_int('min_samples_leaf', 2, 256)
  
  
  model = RandomForestClassifier(n_estimators = n_estimators_hp, 
                         max_depth = max_depth_hp, 
                         min_samples_split = min_child_samples_hp,
                         min_samples_leaf = num_leaves_hp,
                         
                         random_state = 0,class_weight="balanced",n_jobs = -1)
  
  model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
  
  pred_probs = model.predict_proba(df_val[df_val.columns[:-1]])
  
  return roc_auc_score(df_val[df_val.columns[-1]], pred_probs[:,1])
  #return precision_score(y_test, y_pred)
 
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2022-11-25 15:27:41,346] A new study created in memory with name: no-name-67e5e267-ed43-4946-b0f7-f9fabb5078ce
# [I 2022-11-25 15:27:43,571] Trial 0 finished with value: 0.6585114473262889 and parameters: {'n_estimators': 714, 'max_depth': 61, 'min_samples_split': 23, 'min_samples_leaf': 232}. Best is trial 0 with value: 0.6585114473262889.
# [I 2022-11-25 15:27:45,831] Trial 1 finished with value: 0.6582112552033301 and parameters: {'n_estimators': 633, 'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 241}. Best is trial 0 with value: 0.6585114473262889.
# [I 2022-11-25 15:27:46,329] Trial 2 finished with value: 0.6944244316362472 and parameters: {'n_estimators': 116, 'max_depth': 97, 'min_samples_split': 26, 'min_samples_leaf': 20}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:27:48,808] Trial 3 finished with value: 0.6807056516170349 and parameters: {'n_estimators': 576, 'max_depth': 31, 'min_samples_split': 46, 'min_samples_leaf': 66}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:27:51,516] Trial 4 finished with value: 0.6561299231508164 and parameters: {'n_estimators': 773, 'max_depth': 80, 'min_samples_split': 14, 'min_samples_leaf': 201}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:27:53,528] Trial 5 finished with value: 0.6893812039705411 and parameters: {'n_estimators': 541, 'max_depth': 13, 'min_samples_split': 43, 'min_samples_leaf': 27}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:27:56,682] Trial 6 finished with value: 0.672950688440602 and parameters: {'n_estimators': 952, 'max_depth': 98, 'min_samples_split': 38, 'min_samples_leaf': 84}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:27:58,583] Trial 7 finished with value: 0.6557496797950688 and parameters: {'n_estimators': 479, 'max_depth': 96, 'min_samples_split': 60, 'min_samples_leaf': 227}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:27:58,798] Trial 8 finished with value: 0.6791546589817483 and parameters: {'n_estimators': 73, 'max_depth': 82, 'min_samples_split': 93, 'min_samples_leaf': 44}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:28:01,544] Trial 9 finished with value: 0.6567803394172271 and parameters: {'n_estimators': 740, 'max_depth': 10, 'min_samples_split': 36, 'min_samples_leaf': 184}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:28:01,720] Trial 10 finished with value: 0.6441122318283702 and parameters: {'n_estimators': 59, 'max_depth': 51, 'min_samples_split': 70, 'min_samples_leaf': 128}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:28:02,784] Trial 11 finished with value: 0.6942643291706692 and parameters: {'n_estimators': 326, 'max_depth': 45, 'min_samples_split': 31, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.6944244316362472.
# [I 2022-11-25 15:28:04,010] Trial 12 finished with value: 0.6978766410502721 and parameters: {'n_estimators': 286, 'max_depth': 48, 'min_samples_split': 27, 'min_samples_leaf': 6}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:04,903] Trial 13 finished with value: 0.6708293307716939 and parameters: {'n_estimators': 225, 'max_depth': 65, 'min_samples_split': 58, 'min_samples_leaf': 99}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:05,868] Trial 14 finished with value: 0.6934538104386807 and parameters: {'n_estimators': 277, 'max_depth': 37, 'min_samples_split': 25, 'min_samples_leaf': 6}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:07,227] Trial 15 finished with value: 0.6803254082612873 and parameters: {'n_estimators': 412, 'max_depth': 74, 'min_samples_split': 75, 'min_samples_leaf': 57}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:07,935] Trial 16 finished with value: 0.6547590457893051 and parameters: {'n_estimators': 208, 'max_depth': 35, 'min_samples_split': 12, 'min_samples_leaf': 130}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:08,359] Trial 17 finished with value: 0.686439321165546 and parameters: {'n_estimators': 149, 'max_depth': 65, 'min_samples_split': 51, 'min_samples_leaf': 30}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:10,028] Trial 18 finished with value: 0.6639048991354466 and parameters: {'n_estimators': 375, 'max_depth': 24, 'min_samples_split': 25, 'min_samples_leaf': 122}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:10,384] Trial 19 finished with value: 0.6573607108549472 and parameters: {'n_estimators': 148, 'max_depth': 45, 'min_samples_split': 91, 'min_samples_leaf': 152}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:11,146] Trial 20 finished with value: 0.6777137367915466 and parameters: {'n_estimators': 288, 'max_depth': 92, 'min_samples_split': 31, 'min_samples_leaf': 78}. Best is trial 12 with value: 0.6978766410502721.
# [I 2022-11-25 15:28:12,164] Trial 21 finished with value: 0.701839177073327 and parameters: {'n_estimators': 370, 'max_depth': 45, 'min_samples_split': 30, 'min_samples_leaf': 4}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:13,860] Trial 22 finished with value: 0.6867895453089977 and parameters: {'n_estimators': 439, 'max_depth': 50, 'min_samples_split': 21, 'min_samples_leaf': 24}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:15,086] Trial 23 finished with value: 0.698096781940442 and parameters: {'n_estimators': 356, 'max_depth': 58, 'min_samples_split': 33, 'min_samples_leaf': 6}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:16,365] Trial 24 finished with value: 0.6820765289785463 and parameters: {'n_estimators': 354, 'max_depth': 57, 'min_samples_split': 39, 'min_samples_leaf': 44}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:18,007] Trial 25 finished with value: 0.6923430995837336 and parameters: {'n_estimators': 464, 'max_depth': 44, 'min_samples_split': 52, 'min_samples_leaf': 3}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:18,830] Trial 26 finished with value: 0.685588776817163 and parameters: {'n_estimators': 219, 'max_depth': 55, 'min_samples_split': 33, 'min_samples_leaf': 50}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:19,880] Trial 27 finished with value: 0.6812259846301633 and parameters: {'n_estimators': 284, 'max_depth': 72, 'min_samples_split': 18, 'min_samples_leaf': 37}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:21,454] Trial 28 finished with value: 0.6723903298110792 and parameters: {'n_estimators': 390, 'max_depth': 28, 'min_samples_split': 44, 'min_samples_leaf': 102}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:23,588] Trial 29 finished with value: 0.6792547230227346 and parameters: {'n_estimators': 589, 'max_depth': 40, 'min_samples_split': 10, 'min_samples_leaf': 70}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:25,361] Trial 30 finished with value: 0.6909922350304194 and parameters: {'n_estimators': 488, 'max_depth': 60, 'min_samples_split': 65, 'min_samples_leaf': 15}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:25,883] Trial 31 finished with value: 0.6952549631764329 and parameters: {'n_estimators': 161, 'max_depth': 87, 'min_samples_split': 27, 'min_samples_leaf': 19}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:26,506] Trial 32 finished with value: 0.6881904418828051 and parameters: {'n_estimators': 199, 'max_depth': 50, 'min_samples_split': 27, 'min_samples_leaf': 17}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:27,608] Trial 33 finished with value: 0.6952049311559398 and parameters: {'n_estimators': 321, 'max_depth': 84, 'min_samples_split': 19, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:30,014] Trial 34 finished with value: 0.6822766570605187 and parameters: {'n_estimators': 660, 'max_depth': 23, 'min_samples_split': 30, 'min_samples_leaf': 35}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:30,872] Trial 35 finished with value: 0.682857028498239 and parameters: {'n_estimators': 253, 'max_depth': 89, 'min_samples_split': 47, 'min_samples_leaf': 58}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:33,433] Trial 36 finished with value: 0.6906520172910663 and parameters: {'n_estimators': 857, 'max_depth': 72, 'min_samples_split': 40, 'min_samples_leaf': 16}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:33,816] Trial 37 finished with value: 0.689411223182837 and parameters: {'n_estimators': 145, 'max_depth': 64, 'min_samples_split': 16, 'min_samples_leaf': 24}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:34,877] Trial 38 finished with value: 0.6846581812359911 and parameters: {'n_estimators': 529, 'max_depth': 41, 'min_samples_split': 22, 'min_samples_leaf': 36}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:35,146] Trial 39 finished with value: 0.6488552673711175 and parameters: {'n_estimators': 106, 'max_depth': 33, 'min_samples_split': 35, 'min_samples_leaf': 169}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:35,982] Trial 40 finished with value: 0.6525976625040026 and parameters: {'n_estimators': 331, 'max_depth': 79, 'min_samples_split': 27, 'min_samples_leaf': 237}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:36,906] Trial 41 finished with value: 0.6962856227985911 and parameters: {'n_estimators': 337, 'max_depth': 84, 'min_samples_split': 18, 'min_samples_leaf': 9}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:37,947] Trial 42 finished with value: 0.693073567082933 and parameters: {'n_estimators': 425, 'max_depth': 86, 'min_samples_split': 17, 'min_samples_leaf': 15}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:38,371] Trial 43 finished with value: 0.6535582772974704 and parameters: {'n_estimators': 180, 'max_depth': 100, 'min_samples_split': 21, 'min_samples_leaf': 213}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:39,122] Trial 44 finished with value: 0.6963456612231828 and parameters: {'n_estimators': 266, 'max_depth': 94, 'min_samples_split': 14, 'min_samples_leaf': 11}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:40,142] Trial 45 finished with value: 0.6849483669548512 and parameters: {'n_estimators': 374, 'max_depth': 94, 'min_samples_split': 13, 'min_samples_leaf': 48}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:41,020] Trial 46 finished with value: 0.6937239833493436 and parameters: {'n_estimators': 261, 'max_depth': 79, 'min_samples_split': 15, 'min_samples_leaf': 9}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:41,838] Trial 47 finished with value: 0.6861991674671789 and parameters: {'n_estimators': 309, 'max_depth': 69, 'min_samples_split': 23, 'min_samples_leaf': 29}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:43,156] Trial 48 finished with value: 0.6802753762407941 and parameters: {'n_estimators': 499, 'max_depth': 53, 'min_samples_split': 10, 'min_samples_leaf': 61}. Best is trial 21 with value: 0.701839177073327.
# [I 2022-11-25 15:28:43,803] Trial 49 finished with value: 0.6993175632404739 and parameters: {'n_estimators': 247, 'max_depth': 91, 'min_samples_split': 36, 'min_samples_leaf': 2}. Best is trial 21 with value: 0.701839177073327.

# %%
print('Best trial:', study.best_trial.params)
trial = study.best_trial
print("  Value: {}".format(trial.value))

# Best trial: {'n_estimators': 370, 'max_depth': 45, 'min_samples_split': 30, 'min_samples_leaf': 4}
#   Value: 0.701839177073327
# Out:
# Best trial: {'n_estimators': 370, 'max_depth': 45, 'min_samples_split': 30, 'min_samples_leaf': 4}
#   Value: 0.701839177073327

# %%
# model = LGBMClassifier(**study.best_trial.params, random_state = 0,is_unbalance=True )

model = RandomForestClassifier(**{'n_estimators': 370, 'max_depth': 45, 'min_samples_split': 30, 'min_samples_leaf': 4},random_state = 0 ,class_weight="balanced",n_jobs = -1)
 
model.fit(df_train[df_train.columns[:-1]], df_train[df_train.columns[-1]])
 
roc_auc_score(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
# Out:
# 0.7064502704952144

# %%
fpr, tpr, _ = roc_curve(df_test[df_test.columns[-1]], model.predict_proba(df_test[df_test.columns[:-1]])[:,1])
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve Random Forest (area = %0.2f)" % roc_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()

# %%
print(classification_report(df_test[df_test.columns[-1]], model.predict(df_test[df_test.columns[:-1]])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79       356
#            1       0.46      0.49      0.47       135
#
#     accuracy                           0.70       491
#    macro avg       0.63      0.63      0.63       491
# weighted avg       0.71      0.70      0.70       491

# %%
feature_imp = pd.DataFrame(sorted(zip(model.feature_importances_,df_train_x.columns),reverse=True), columns=['Value','Feature'])
feature_imp
# Out:
#        Value                            Feature
# 0   0.064495         activity_inf_unknown_count
# 1   0.058258      activity_inf_stationary_count
# 2   0.053350                         weeknumber
# 3   0.053110                                day
# 4   0.040338  app_usage_baseActivity_numRunning
# ..       ...                                ...
# 81  0.000000                            grade_B
# 82  0.000000                        grade_A_min
# 83  0.000000                  effort_Class 2 no
# 84  0.000000               challenge_Class 2 no
# 85  0.000000            audio_inf_unknown_count
#
# [86 rows x 2 columns]

# %% [markdown]
# ## End
